# %%
import os
import sys
import re

project_root = "/root/work/tvm-ansor"
os.environ["TVM_HOME"] = f"{project_root}"
os.environ["TVM_LIBRARY_PATH"] = f"{project_root}/build-release"
if f"{project_root}/python" not in sys.path:
    sys.path.insert(0, f"{project_root}/python")

sys.path = [p for p in sys.path if not p.startswith(f"{project_root}/build")]
sys.path.append(f"{project_root}/build-release")
os.environ["LD_LIBRARY_PATH"] = f"{project_root}/build-release:" + os.environ.get("LD_LIBRARY_PATH", "")
from tvm.auto_scheduler.search_policy import CustomPrintState


ppath = os.environ.get("PYTHONPATH")
buildpath = os.environ.get("TVM_LIBRARY_PATH")
gdb_mode = os.environ.get("TVM_GDB_MODE")
use_ncu = os.environ.get("USE_NCU")

# breakpoint()
import util_manager
if gdb_mode == "1":
    gdb_manager = util_manager.GDBManager()
    gdb_manager.gdb_log_set()

print("="*80)
print("PYTHONPATH :", ppath)
print("TVM_LIBRARY_PATH :", buildpath)
print("USE_NCU :", use_ncu)

if buildpath.endswith("build"):
    print("DEBUG MODE")
elif buildpath.endswith("release"):
    print("RELEASE MODE")
else:
    AssertionError("Set Environment release/debug")

import numpy as np
from util_manager import PathManager, get_network, get_arg
import tvm
from tvm import relay, auto_scheduler
from tvm.contrib import graph_executor
import argparse
from tvm.auto_scheduler.feature import get_per_store_features_from_file

TARGET = tvm.target.Target("cuda")

def get_tasks(mod, params, path_manager, verbose=True, get_pkl=True):
    if get_pkl:
        tasks, task_weights = path_manager.tasks_pkl_use()
    
    if get_pkl is False or tasks is None:
        print("Extract tasks...")
        tasks, task_weights = auto_scheduler.extract_tasks(mod["main"], params, TARGET)
        if path_manager.tasks_pkl_check() is False:
            path_manager.tasks_pkl_save(tasks, task_weights)

    if verbose:
        for idx, task in enumerate(tasks):
            print("========== Task %d : %s  (workload key: %s) ==========" % (idx, task.desc, task.workload_key))
            print(task.compute_dag)
            # breakpoint()
    
    print(f"Total tasks length : {len(tasks)}")
    # breakpoint()
    return tasks, task_weights
# Out:
# ================================================================================
# PYTHONPATH : None
# TVM_LIBRARY_PATH : /root/work/tvm-ansor/build-release
# USE_NCU : None
# RELEASE MODE

# %%
from types import SimpleNamespace


args = SimpleNamespace(
    network="resnet_18",
    batch_size = 1,
    dtype="float32",
    layout="NHWC",
    timenow=None,
    json=None
)


# 네트워크 불러오기
mod, params, input_shape, output_shape = get_network(args.network, args.batch_size, args.layout, dtype=args.dtype)


# 경로 설정
# path_manager = PathManager(network, input_shape, args, gdb_mode)
path_manager = PathManager(args.network, input_shape, args, gdb_mode, json="/root/work/tvm-ansor/gallery/logs_json/tmp.json")


# task 추출
tasks, task_weights = get_tasks(None, params, path_manager, verbose=False, get_pkl=True)

# task.desc 기준으로 정렬
tasks, task_weights = zip(*sorted(zip(tasks, task_weights), key=lambda x: x[0].desc))
search_policies = []
for idx, (task, weight) in enumerate(zip(tasks, task_weights)):
    print(f"T{idx} : {task.desc} ({weight})")
        
    search_policies.append(
                auto_scheduler.SketchPolicy(
                    task,
                    auto_scheduler.XGBModel(),
                )
            )
# Out:
# Getting network resnet_18...
#
# Using json : /root/work/tvm-ansor/gallery/logs_json/tmp.json
# Load tasks from /root/work/tvm-ansor/gallery/ansor_tasks_pkl/resnet_18-(1,224,224,3).pkl
# Total tasks length : 24
# T0 : vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add (1)
# T1 : vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_1 (1)
# T2 : vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_2 (1)
# T3 : vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_3 (1)
# T4 : vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_add_nn_relu (1)
# T5 : vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_add_nn_relu_1 (1)
# T6 : vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_add_nn_relu_2 (1)
# T7 : vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_multiply_add_nn_re_a4e88f85cf7823fc_ (1)
# T8 : vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu (2)
# T9 : vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 (1)
# T10 : vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_2 (1)
# T11 : vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_3 (1)
# T12 : vm_mod_fused_nn_conv2d (1)
# T13 : vm_mod_fused_nn_conv2d_1 (1)
# T14 : vm_mod_fused_nn_conv2d_2 (1)
# T15 : vm_mod_fused_nn_conv2d_3 (1)
# T16 : vm_mod_fused_nn_conv2d_add_nn_relu (1)
# T17 : vm_mod_fused_nn_conv2d_add_nn_relu_1 (1)
# T18 : vm_mod_fused_nn_conv2d_add_nn_relu_2 (1)
# T19 : vm_mod_fused_nn_conv2d_add_nn_relu_3 (1)
# T20 : vm_mod_fused_nn_dense_add (1)
# T21 : vm_mod_fused_nn_global_avg_pool2d (1)
# T22 : vm_mod_fused_nn_max_pool2d_add_nn_relu (1)
# T23 : vm_mod_fused_nn_softmax (1)

# %%
for idx, task in enumerate(tasks):
    print(f"Task {idx}: {task.desc} : {task.workload_key}")
# Out:
# Task 0: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add : ["10b8215aaf2e14d47d40b4093e6f41a0", [1, 56, 56, 64], [6, 6, 64, 64], [1, 56, 56, 64], [1, 56, 56, 64]]
# Task 1: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_1 : ["25577781e50c611c2e45e73c1cb3a6ca", [1, 28, 28, 128], [4, 4, 128, 128], [1, 28, 28, 128], [1, 28, 28, 128]]
# Task 2: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_2 : ["7f3fee61bc3c2604395f5d343b840b7c", [1, 14, 14, 256], [4, 4, 256, 256], [1, 14, 14, 256], [1, 14, 14, 256]]
# Task 3: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_3 : ["d78e8eb6021c4cdda0ad7775d10f751a", [1, 7, 7, 512], [4, 4, 512, 512], [1, 7, 7, 512], [1, 7, 7, 512]]
# Task 4: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_add_nn_relu : ["6c4f6234946e16bcf9e48bdf289f9200", [1, 56, 56, 64], [6, 6, 64, 64], [1, 56, 56, 64], [1, 1, 1, 64], [1, 56, 56, 64]]
# Task 5: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_add_nn_relu_1 : ["f19692ed81d032b1697c08adee62f9a5", [1, 28, 28, 128], [4, 4, 128, 128], [1, 28, 28, 128], [1, 1, 1, 128], [1, 28, 28, 128]]
# Task 6: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_add_nn_relu_2 : ["64b7ce5264a64cb340d78b444b0325e6", [1, 14, 14, 256], [4, 4, 256, 256], [1, 14, 14, 256], [1, 1, 1, 256], [1, 14, 14, 256]]
# Task 7: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_multiply_add_nn_re_a4e88f85cf7823fc_ : ["a3df19e5b88592ef5a9ce584a1ca3010", [1, 7, 7, 512], [4, 4, 512, 512], [1, 7, 7, 512], [1, 1, 1, 512], [1, 1, 1, 512], [1, 7, 7, 512]]
# Task 8: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu : ["7c2a4f1f432f81c44985590780dfb52d", [1, 56, 56, 64], [6, 6, 64, 64], [1, 1, 1, 64], [1, 56, 56, 64]]
# Task 9: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 : ["0bcf718c0e6566bcd6c3b1437a3b6291", [1, 28, 28, 128], [4, 4, 128, 128], [1, 1, 1, 128], [1, 28, 28, 128]]
# Task 10: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_2 : ["1097323f3970e5c881ad3a0028ca79cb", [1, 14, 14, 256], [4, 4, 256, 256], [1, 1, 1, 256], [1, 14, 14, 256]]
# Task 11: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_3 : ["40b1cf1fd37b0ef111b3cc0247302508", [1, 7, 7, 512], [4, 4, 512, 512], [1, 1, 1, 512], [1, 7, 7, 512]]
# Task 12: vm_mod_fused_nn_conv2d : ["2d10de6646307f0e3e5cf4b31c20e69b", [1, 56, 56, 64], [1, 1, 64, 64], [1, 56, 56, 64]]
# Task 13: vm_mod_fused_nn_conv2d_1 : ["0fad1b42d0d33418e0a8d15d3bbad3c9", [1, 56, 56, 64], [1, 1, 64, 128], [1, 28, 28, 128]]
# Task 14: vm_mod_fused_nn_conv2d_2 : ["0fad1b42d0d33418e0a8d15d3bbad3c9", [1, 28, 28, 128], [1, 1, 128, 256], [1, 14, 14, 256]]
# Task 15: vm_mod_fused_nn_conv2d_3 : ["0fad1b42d0d33418e0a8d15d3bbad3c9", [1, 14, 14, 256], [1, 1, 256, 512], [1, 7, 7, 512]]
# Task 16: vm_mod_fused_nn_conv2d_add_nn_relu : ["07f9fcad27bdd3233f86fe35a5185d33", [1, 224, 224, 3], [7, 7, 3, 64], [1, 1, 1, 64], [1, 112, 112, 64]]
# Task 17: vm_mod_fused_nn_conv2d_add_nn_relu_1 : ["07f9fcad27bdd3233f86fe35a5185d33", [1, 56, 56, 64], [3, 3, 64, 128], [1, 1, 1, 128], [1, 28, 28, 128]]
# Task 18: vm_mod_fused_nn_conv2d_add_nn_relu_2 : ["07f9fcad27bdd3233f86fe35a5185d33", [1, 28, 28, 128], [3, 3, 128, 256], [1, 1, 1, 256], [1, 14, 14, 256]]
# Task 19: vm_mod_fused_nn_conv2d_add_nn_relu_3 : ["07f9fcad27bdd3233f86fe35a5185d33", [1, 14, 14, 256], [3, 3, 256, 512], [1, 1, 1, 512], [1, 7, 7, 512]]
# Task 20: vm_mod_fused_nn_dense_add : ["08f7449d79e570b7274174709e5e5e01", [1, 512], [1000, 512], [1, 1000], [1, 1000]]
# Task 21: vm_mod_fused_nn_global_avg_pool2d : ["8c53ca2904398da2889aa7508082d7bb", [1, 7, 7, 512], [1, 1, 1, 512]]
# Task 22: vm_mod_fused_nn_max_pool2d_add_nn_relu : ["6d012ba18a086c11ee2b85c7324e16f2", [1, 112, 112, 64], [1, 1, 1, 64], [1, 56, 56, 64]]
# Task 23: vm_mod_fused_nn_softmax : ["7d79c516e212fe1d73f5dbb90eaca2cf", [1, 1000], [1, 1000]]

# %%
"""
분석: .shared buffer size가 어떤 split factor에 의해 결정되는지 추적
같은 sketch에서 tile 값만 다른 여러 state를 만들어서 비교
"""
from tvm.auto_scheduler.search_policy import CustomPrintState

# dense_add task 사용 (가장 간단한 matmul 형태)
task_idx = 10
task = tasks[task_idx]
policy = search_policies[task_idx]

print(f"Task: {task.desc}")
print(f"Compute DAG:\n{task.compute_dag}")
print(f"Hardware: max_shared_memory={task.hardware_params.max_shared_memory_per_block}")
print("=" * 80)

# 여러 state 샘플링 (인자 없음)
states = policy.sample_initial_population()
print(f"Sampled {len(states)} states")

# 첫 번째 state의 구조 확인
s0 = states[0]
print("\n=== State 0 ===")
print(CustomPrintState(s0, delete_trivial_loop=False, dag_show=False))
print("\n=== Transform Steps ===")
for i, step in enumerate(s0.transform_steps):
    print(f"Step {i}: {step}")
# Out:
# Task: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_2
# Compute DAG:
# p0 = PLACEHOLDER [1, 14, 14, 256]
# data_pad(i0, i1, i2, i3) = tir.if_then_else(((((i1 >= 1) && (i1 < 15)) && (i2 >= 1)) && (i2 < 15)), p0[i0, (i1 - 1), (i2 - 1), i3], 0f)
# input_tile(eps, nu, p, ci) = data_pad[floordiv(p, 49), ((floormod(floordiv(p, 7), 7)*2) + eps), ((floormod(p, 7)*2) + nu), ci]
# B(i, j) = select(((floormod(i, 4) == 3) && (floormod(j, 4) == 3)), 1f, select(((floormod(i, 4) == 3) && (floormod(j, 4) == 2)),  ..(OMITTED).. ormod(i, 4) == 0) && (floormod(j, 4) == 1)), 0f, select(((floormod(i, 4) == 0) && (floormod(j, 4) == 0)), 1f, 0f))))))))))))))))
# data_pack(eps, nu, p, ci) += ((input_tile[r_a, r_b, p, ci]*B[r_a, eps])*B[r_b, nu])
# p1 = PLACEHOLDER [4, 4, 256, 256]
# bgemm(eps, nu, p, co) += (data_pack[eps, nu, p, ci]*p1[eps, nu, co, ci])
# A(i, j) = select(((floormod(i, 4) == 3) && (floormod(j, 2) == 1)), 1f, select(((floormod(i, 4) == 3) && (floormod(j, 2) == 0)),  ..(OMITTED).. ct(((floormod(i, 4) == 0) && (floormod(j, 2) == 1)), 0f, select(((floormod(i, 4) == 0) && (floormod(j, 2) == 0)), 1f, 0f))))))))
# inverse(vh, vw, p, co) += ((bgemm[r_a, r_b, p, co]*A[r_a, vh])*A[r_b, vw])
# conv2d_winograd(n, h, w, co) = inverse[floormod(h, 2), floormod(w, 2), ((((n*7)*7) + (floordiv(h, 2)*7)) + floordiv(w, 2)), co]
# p2 = PLACEHOLDER [1, 1, 1, 256]
# T_add(ax0, ax1, ax2, ax3) = (conv2d_winograd[ax0, ax1, ax2, ax3] + p2[ax0, 0, 0, ax3])
# T_relu(ax0, ax1, ax2, ax3) = max(T_add[ax0, ax1, ax2, ax3], 0f)
#
# Hardware: max_shared_memory=49152
# ================================================================================
# Generate Sketches		#s: 1
# Sampled 74 statesSample Initial Population	#s: 74	fail_ct: 1974	Time elapsed: 5.51
#
#
# === State 0 ===
# Placeholder: p0, p1, p2
# data_pack auto_unroll: 1024
# blockIdx.x p.0@ci.0@p.1@ci.1@.0 (0,392)
#   threadIdx.x p.0@ci.0@p.1@ci.1@.1 (0,32)
#     for eps (0,4)
#       for nu (0,4)
#         for p ((blockIdx_x * 32 + threadIdx_x) % 49,1)
#           for ci ((blockIdx_x * 32 + threadIdx_x) // 49,1)
#             input_tile = ...
#     unroll eps (0,4)
#       unroll nu (0,4)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             data_pack = ...
# blockIdx.x eps.0@nu.0@p.0@co.0@ (0,1)
#   vthread eps.1@nu.1@p.1@co.1@ (0,4)
#     threadIdx.x eps.2@nu.2@p.2@co.2@ (0,64)
#       bgemm.local auto_unroll: 64
#       for eps_c.0 (0,1)
#         for nu_c.0 (0,1)
#           for p_c.0 (0,1)
#             for co_c.0 (0,1)
#               for eps_c.1 (0,1)
#                 for nu_c.1 (0,1)
#                   for p_c.1 (0,1)
#                     for co_c.1 (0,1)
#                       for eps_c.2 (0,1)
#                         for nu_c.2 (0,1)
#                           for p_c.2 (0,1)
#                             for co_c.2 (0,1)
#                               for ci.0 (0,256)
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,64)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,64)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       p1.shared = ...
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,13)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,64)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       data_pack.shared = ...
#                                 for ci.1 (0,1)
#                                   for eps_c.3 (0,1)
#                                     for nu_c.3 (0,1)
#                                       for p_c.3 (0,7)
#                                         for co_c.3 (0,4)
#                                           for ci.2 (0,1)
#                                             for eps_c.4 (0,2)
#                                               for nu_c.4 (0,1)
#                                                 for p_c.4 (0,7)
#                                                   for co_c.4 (0,2)
#                                                     bgemm.local = ...
#       for eps.3 (0,2)
#         for nu.3 (0,1)
#           for p.3 (0,49)
#             for co.3 (0,8)
#               bgemm = ...
# inverse auto_unroll: 1024
# blockIdx.x p.0@co.0@p.1@co.1@.0 (0,392)
#   threadIdx.x p.0@co.0@p.1@co.1@.1 (0,32)
#     unroll vh (0,2)
#       unroll vw (0,2)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             inverse = ...
# blockIdx.x ax0@ax1@ax2@ax3@.0 (0,1568)
#   threadIdx.x ax0@ax1@ax2@ax3@.1 (0,32)
#     T_relu = ...
#
#
# === Transform Steps ===
# Step 0: auto_scheduler.ComputeInlineStep(0x3d629968)
# Step 1: auto_scheduler.ComputeInlineStep(0x39fd7f38)
# Step 2: auto_scheduler.AnnotationStep(0x39ec7968)
# Step 3: auto_scheduler.AnnotationStep(0x3c905ca8)
# Step 4: auto_scheduler.SplitStep(0x7f1c3c018f88)
# Step 5: auto_scheduler.SplitStep(0x7f1c3c00dbf8)
# Step 6: auto_scheduler.AnnotationStep(0x3a187348)
# Step 7: auto_scheduler.AnnotationStep(0x3c9fbef8)
# Step 8: auto_scheduler.ReorderStep(0x3c4b60a8)
# Step 9: auto_scheduler.ComputeInlineStep(0x3c4b6108)
# Step 10: auto_scheduler.CacheWriteStep(0x3ad33768)
# Step 11: auto_scheduler.SplitStep(0x7f1c3c0116b8)
# Step 12: auto_scheduler.SplitStep(0x7f1c3c02c7d8)
# Step 13: auto_scheduler.SplitStep(0x7f1c3c011478)
# Step 14: auto_scheduler.SplitStep(0x7f1c3c005dd8)
# Step 15: auto_scheduler.SplitStep(0x7f1c3c011858)
# Step 16: auto_scheduler.ReorderStep(0x3c95d718)
# Step 17: auto_scheduler.FollowSplitStep(0x3d3fb6e8)
# Step 18: auto_scheduler.FollowSplitStep(0x3d3fc1e8)
# Step 19: auto_scheduler.FollowSplitStep(0x3d3fad58)
# Step 20: auto_scheduler.FollowSplitStep(0x3c8d0008)
# Step 21: auto_scheduler.ReorderStep(0x3c8d0738)
# Step 22: auto_scheduler.ComputeAtStep(0x3d3fab98)
# Step 23: auto_scheduler.CacheReadStep(0x3c4b6c38)
# Step 24: auto_scheduler.ComputeAtStep(0x3c90e718)
# Step 25: auto_scheduler.CacheReadStep(0x3c8d1df8)
# Step 26: auto_scheduler.ComputeAtStep(0x3c914758)
# Step 27: auto_scheduler.AnnotationStep(0x3c913cb8)
# Step 28: auto_scheduler.AnnotationStep(0x3c9157b8)
# Step 29: auto_scheduler.SplitStep(0x7f1c3c00ed98)
# Step 30: auto_scheduler.SplitStep(0x7f1c3c021028)
# Step 31: auto_scheduler.AnnotationStep(0x3c914918)
# Step 32: auto_scheduler.AnnotationStep(0x3c914d98)
# Step 33: auto_scheduler.ReorderStep(0x3d43e838)
# Step 34: auto_scheduler.ComputeInlineStep(0x3c911878)
# Step 35: auto_scheduler.ComputeAtStep(0x3d43f8e8)
# Step 36: auto_scheduler.ComputeInlineStep(0x3d4f87a8)
# Step 37: auto_scheduler.FuseStep(0x7f1c3c02a358)
# Step 38: auto_scheduler.SplitStep(0x7f1c3c004b78)
# Step 39: auto_scheduler.AnnotationStep(0x7f1c3c005cf8)
# Step 40: auto_scheduler.AnnotationStep(0x7f1c3c008b48)
# Step 41: auto_scheduler.FuseStep(0x7f1c3c009198)
# Step 42: auto_scheduler.SplitStep(0x7f1c3c00e068)
# Step 43: auto_scheduler.AnnotationStep(0x7f1c3c022208)
# Step 44: auto_scheduler.AnnotationStep(0x7f1c3c00d6c8)
# Step 45: auto_scheduler.FuseStep(0x7f1c3c02b048)
# Step 46: auto_scheduler.AnnotationStep(0x7f1c3c00cd28)
# Step 47: auto_scheduler.FuseStep(0x7f1c3c005a58)
# Step 48: auto_scheduler.AnnotationStep(0x7f1c3c02b4c8)
# Step 49: auto_scheduler.FuseStep(0x7f1c3c0338f8)
# Step 50: auto_scheduler.AnnotationStep(0x7f1c3c02c658)
# Step 51: auto_scheduler.FuseStep(0x7f1c3c02e888)
# Step 52: auto_scheduler.SplitStep(0x7f1c3c0313b8)
# Step 53: auto_scheduler.AnnotationStep(0x7f1c3c023938)
# Step 54: auto_scheduler.FollowFusedSplitStep(0x7f1c3c00dad8)
# Step 55: auto_scheduler.AnnotationStep(0x7f1c3c03b478)
# Step 56: auto_scheduler.FuseStep(0x7f1c3c009428)
# Step 57: auto_scheduler.SplitStep(0x7f1c3c00d618)
# Step 58: auto_scheduler.AnnotationStep(0x7f1c3c01fa08)
# Step 59: auto_scheduler.FollowFusedSplitStep(0x7f1c3c037668)
# Step 60: auto_scheduler.AnnotationStep(0x7f1c3c030c48)
# Step 61: auto_scheduler.FuseStep(0x7f1c3c01f3a8)
# Step 62: auto_scheduler.SplitStep(0x7f1c3c017d68)
# Step 63: auto_scheduler.AnnotationStep(0x7f1c3c007388)
# Step 64: auto_scheduler.AnnotationStep(0x7f1c3c032e18)
# Step 65: auto_scheduler.PragmaStep(0x7f1c3c01ea88)
# Step 66: auto_scheduler.PragmaStep(0x7f1c3c032718)
# Step 67: auto_scheduler.PragmaStep(0x7f1c3c0217c8)

# %%
len(tasks[10].compute_dag.ops)
# Out:
# 13

# %%
print(tasks[10].desc)
print(tasks[10].compute_dag)
print("="*80)
compute_ops_n = 0
for s_id, op in enumerate(tasks[10].compute_dag.ops):
    print(f"Stage{s_id+1}: {op}")
    if isinstance(op, tvm.te.tensor.ComputeOp):
        compute_ops_n += 1
print("="*80)
print(tasks[10].compute_dag.init_state)
print("="*80)
s = search_policies[10].sample_initial_population()[0]
for step in s.transform_steps:
    print(step)
print("="*80)
print(CustomPrintState(s, delete_trivial_loop=False, dag_show=False))
# Out:
# vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_2
# p0 = PLACEHOLDER [1, 14, 14, 256]
# data_pad(i0, i1, i2, i3) = tir.if_then_else(((((i1 >= 1) && (i1 < 15)) && (i2 >= 1)) && (i2 < 15)), p0[i0, (i1 - 1), (i2 - 1), i3], 0f)
# input_tile(eps, nu, p, ci) = data_pad[floordiv(p, 49), ((floormod(floordiv(p, 7), 7)*2) + eps), ((floormod(p, 7)*2) + nu), ci]
# B(i, j) = select(((floormod(i, 4) == 3) && (floormod(j, 4) == 3)), 1f, select(((floormod(i, 4) == 3) && (floormod(j, 4) == 2)),  ..(OMITTED).. ormod(i, 4) == 0) && (floormod(j, 4) == 1)), 0f, select(((floormod(i, 4) == 0) && (floormod(j, 4) == 0)), 1f, 0f))))))))))))))))
# data_pack(eps, nu, p, ci) += ((input_tile[r_a, r_b, p, ci]*B[r_a, eps])*B[r_b, nu])
# p1 = PLACEHOLDER [4, 4, 256, 256]
# bgemm(eps, nu, p, co) += (data_pack[eps, nu, p, ci]*p1[eps, nu, co, ci])
# A(i, j) = select(((floormod(i, 4) == 3) && (floormod(j, 2) == 1)), 1f, select(((floormod(i, 4) == 3) && (floormod(j, 2) == 0)),  ..(OMITTED).. ct(((floormod(i, 4) == 0) && (floormod(j, 2) == 1)), 0f, select(((floormod(i, 4) == 0) && (floormod(j, 2) == 0)), 1f, 0f))))))))
# inverse(vh, vw, p, co) += ((bgemm[r_a, r_b, p, co]*A[r_a, vh])*A[r_b, vw])
# conv2d_winograd(n, h, w, co) = inverse[floormod(h, 2), floormod(w, 2), ((((n*7)*7) + (floordiv(h, 2)*7)) + floordiv(w, 2)), co]
# p2 = PLACEHOLDER [1, 1, 1, 256]
# T_add(ax0, ax1, ax2, ax3) = (conv2d_winograd[ax0, ax1, ax2, ax3] + p2[ax0, 0, 0, ax3])
# T_relu(ax0, ax1, ax2, ax3) = max(T_add[ax0, ax1, ax2, ax3], 0f)
#
# ================================================================================
# Stage1: placeholder(p0, 0x3c4de470)
# Stage2: compute(data_pad, body=[T.if_then_else(i1 >= 1 and i1 < 15 and i2 >= 1 and i2 < 15, p0[i0, i1 - 1, i2 - 1, i3], T.float32(0))], axis=[T.iter_var(i0, T.Range(0, 1), "DataPar", ""), T.iter_var(i1, T.Range(0, 16), "DataPar", ""), T.iter_var(i2, T.Range(0, 16), "DataPar", ""), T.iter_var(i3, T.Range(0, 256), "DataPar", "")], reduce_axis=[], tag=injective,pad, attrs={"schedule_rule": "None"})
# Stage3: compute(input_tile, body=[data_pad[p // 49, p // 7 % 7 * 2 + eps, p % 7 * 2 + nu, ci]], axis=[T.iter_var(eps, T.Range(0, 4), "DataPar", ""), T.iter_var(nu, T.Range(0, 4), "DataPar", ""), T.iter_var(p, T.Range(0, 49), "DataPar", ""), T.iter_var(ci, T.Range(0, 256), "DataPar", "")], reduce_axis=[], tag=, attrs={"schedule_rule": "None"})
# Stage4: compute(B, body=[T.Select(i % 4 == 3 and j % 4 == 3, T.float32(1), T.Select(i % 4 == 3 and j % 4 == 2, T.float32(0), T.Select(i % 4 == 3 and j % 4 == 1, T.float32(0), T.Select(i % 4 == 3 and j % 4 == 0, T.float32(0), T.Select(i % 4 == 2 and j % 4 == 3, T.float32(0), T.Select(i % 4 == 2 and j % 4 == 2, T.float32(1), T.Select(i % 4 == 2 and j % 4 == 1, T.float32(1), T.Select(i % 4 == 2 and j % 4 == 0, T.float32(-1), T.Select(i % 4 == 1 and j % 4 == 3, T.float32(-1), T.Select(i % 4 == 1 and j % 4 == 2, T.float32(1), T.Select(i % 4 == 1 and j % 4 == 1, T.float32(-1), T.Select(i % 4 == 1 and j % 4 == 0, T.float32(0), T.Select(i % 4 == 0 and j % 4 == 3, T.float32(0), T.Select(i % 4 == 0 and j % 4 == 2, T.float32(0), T.Select(i % 4 == 0 and j % 4 == 1, T.float32(0), T.Select(i % 4 == 0 and j % 4 == 0, T.float32(1), T.float32(0)))))))))))))))))], axis=[T.iter_var(i, T.Range(0, 4), "DataPar", ""), T.iter_var(j, T.Range(0, 4), "DataPar", "")], reduce_axis=[], tag=, attrs={"const_matrix": T.bool(True), "schedule_rule": "None"})
# Stage5: compute(data_pack, body=[T.reduce(T.comm_reducer(lambda x, y: x + y, [T.float32(0)]), source=[input_tile[r_a, r_b, p, ci] * B[r_a, eps] * B[r_b, nu]], init=[], axis=[T.iter_var(r_a, T.Range(0, 4), "CommReduce", ""), T.iter_var(r_b, T.Range(0, 4), "CommReduce", "")], condition=T.bool(True), value_index=0)], axis=[T.iter_var(eps, T.Range(0, 4), "DataPar", ""), T.iter_var(nu, T.Range(0, 4), "DataPar", ""), T.iter_var(p, T.Range(0, 49), "DataPar", ""), T.iter_var(ci, T.Range(0, 256), "DataPar", "")], reduce_axis=[T.iter_var(r_a, T.Range(0, 4), "CommReduce", ""), T.iter_var(r_b, T.Range(0, 4), "CommReduce", "")], tag=, attrs={"auto_scheduler_simplify_const_tensor_indices": ["eps", "nu", "r_a", "r_b"], "schedule_rule": "conv2d_nhwc_winograd_data_pack"})
# Stage6: placeholder(p1, 0x3c4ebe80)
# Stage7: compute(bgemm, body=[T.reduce(T.comm_reducer(lambda x, y: x + y, [T.float32(0)]), source=[data_pack[eps, nu, p, ci] * p1[eps, nu, co, ci]], init=[], axis=[T.iter_var(ci, T.Range(0, 256), "CommReduce", "")], condition=T.bool(True), value_index=0)], axis=[T.iter_var(eps, T.Range(0, 4), "DataPar", ""), T.iter_var(nu, T.Range(0, 4), "DataPar", ""), T.iter_var(p, T.Range(0, 49), "DataPar", ""), T.iter_var(co, T.Range(0, 256), "DataPar", "")], reduce_axis=[T.iter_var(ci, T.Range(0, 256), "CommReduce", "")], tag=, attrs={"layout_free_placeholders": [Tensor(shape=[4, 4, 256, 256], op.name=p1)]})
# Stage8: compute(A, body=[T.Select(i % 4 == 3 and j % 2 == 1, T.float32(1), T.Select(i % 4 == 3 and j % 2 == 0, T.float32(0), T.Select(i % 4 == 2 and j % 2 == 1, T.float32(1), T.Select(i % 4 == 2 and j % 2 == 0, T.float32(1), T.Select(i % 4 == 1 and j % 2 == 1, T.float32(-1), T.Select(i % 4 == 1 and j % 2 == 0, T.float32(1), T.Select(i % 4 == 0 and j % 2 == 1, T.float32(0), T.Select(i % 4 == 0 and j % 2 == 0, T.float32(1), T.float32(0)))))))))], axis=[T.iter_var(i, T.Range(0, 4), "DataPar", ""), T.iter_var(j, T.Range(0, 2), "DataPar", "")], reduce_axis=[], tag=, attrs={"const_matrix": T.bool(True), "schedule_rule": "None"})
# Stage9: compute(inverse, body=[T.reduce(T.comm_reducer(lambda x, y: x + y, [T.float32(0)]), source=[bgemm[r_a, r_b, p, co] * A[r_a, vh] * A[r_b, vw]], init=[], axis=[T.iter_var(r_a, T.Range(0, 4), "CommReduce", ""), T.iter_var(r_b, T.Range(0, 4), "CommReduce", "")], condition=T.bool(True), value_index=0)], axis=[T.iter_var(vh, T.Range(0, 2), "DataPar", ""), T.iter_var(vw, T.Range(0, 2), "DataPar", ""), T.iter_var(p, T.Range(0, 49), "DataPar", ""), T.iter_var(co, T.Range(0, 256), "DataPar", "")], reduce_axis=[T.iter_var(r_a, T.Range(0, 4), "CommReduce", ""), T.iter_var(r_b, T.Range(0, 4), "CommReduce", "")], tag=, attrs={"auto_scheduler_simplify_const_tensor_indices": ["vh", "vw", "r_a", "r_b"], "schedule_rule": "conv2d_nhwc_winograd_inverse"})
# Stage10: compute(conv2d_winograd, body=[inverse[h % 2, w % 2, n * 7 * 7 + h // 2 * 7 + w // 2, co]], axis=[T.iter_var(n, T.Range(0, 1), "DataPar", ""), T.iter_var(h, T.Range(0, 14), "DataPar", ""), T.iter_var(w, T.Range(0, 14), "DataPar", ""), T.iter_var(co, T.Range(0, 256), "DataPar", "")], reduce_axis=[], tag=, attrs={})
# Stage11: placeholder(p2, 0x3c4d2ed0)
# Stage12: compute(T_add, body=[conv2d_winograd[ax0, ax1, ax2, ax3] + p2[ax0, 0, 0, ax3]], axis=[T.iter_var(ax0, T.Range(0, 1), "DataPar", ""), T.iter_var(ax1, T.Range(0, 14), "DataPar", ""), T.iter_var(ax2, T.Range(0, 14), "DataPar", ""), T.iter_var(ax3, T.Range(0, 256), "DataPar", "")], reduce_axis=[], tag=broadcast, attrs={})
# Stage13: compute(T_relu, body=[T.max(T_add[ax0, ax1, ax2, ax3], T.float32(0))], axis=[T.iter_var(ax0, T.Range(0, 1), "DataPar", ""), T.iter_var(ax1, T.Range(0, 14), "DataPar", ""), T.iter_var(ax2, T.Range(0, 14), "DataPar", ""), T.iter_var(ax3, T.Range(0, 256), "DataPar", "")], reduce_axis=[], tag=elemwise, attrs={})
# ================================================================================
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# for vh (0,2)
#   for vw (0,2)
#     for p (0,49)
#       for co (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             inverse = ...
# for n (0,1)
#   for h (0,14)
#     for w (0,14)
#       for co (0,256)
#         conv2d_winograd = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_add = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Generate Sketches		#s: 1
# Sample Initial Population	#s: 64	fail_ct: 1984	Time elapsed: 4.97
# auto_scheduler.ComputeInlineStep(0x3c4ec098)
# auto_scheduler.ComputeInlineStep(0x3ddd1278)
# auto_scheduler.AnnotationStep(0x3deb4a08)
# auto_scheduler.AnnotationStep(0x3caf0c38)
# auto_scheduler.SplitStep(0x7f1c58090258)
# auto_scheduler.SplitStep(0x7f1c580d1d58)
# auto_scheduler.AnnotationStep(0x3df78598)
# auto_scheduler.AnnotationStep(0x3db9e378)
# auto_scheduler.ReorderStep(0x3c502518)
# auto_scheduler.ComputeInlineStep(0x3e260758)
# auto_scheduler.CacheWriteStep(0x3daea5e8)
# auto_scheduler.SplitStep(0x7f1c5805f8a8)
# auto_scheduler.SplitStep(0x7f1c58118848)
# auto_scheduler.SplitStep(0x7f1c58041ef8)
# auto_scheduler.SplitStep(0x7f1c5804a9f8)
# auto_scheduler.SplitStep(0x7f1c580b6ac8)
# auto_scheduler.ReorderStep(0x3d5804f8)
# auto_scheduler.FollowSplitStep(0x3df10d68)
# auto_scheduler.FollowSplitStep(0x3d5e8888)
# auto_scheduler.FollowSplitStep(0x3dea1508)
# auto_scheduler.FollowSplitStep(0x3c8e61d8)
# auto_scheduler.ReorderStep(0x3e3bde78)
# auto_scheduler.ComputeAtStep(0x3df83878)
# auto_scheduler.CacheReadStep(0x3c9dba38)
# auto_scheduler.ComputeAtStep(0x3d562048)
# auto_scheduler.CacheReadStep(0x3db9d4d8)
# auto_scheduler.ComputeAtStep(0x3deb4998)
# auto_scheduler.AnnotationStep(0x3dec3128)
# auto_scheduler.AnnotationStep(0x3c8ec508)
# auto_scheduler.SplitStep(0x7f1c58106a58)
# auto_scheduler.SplitStep(0x7f1c58005518)
# auto_scheduler.AnnotationStep(0x3caf4248)
# auto_scheduler.AnnotationStep(0x3dae6a08)
# auto_scheduler.ReorderStep(0x3de14eb8)
# auto_scheduler.ComputeInlineStep(0x3d416ab8)
# auto_scheduler.ComputeAtStep(0x3ae7daf8)
# auto_scheduler.ComputeInlineStep(0x3ae7bdf8)
# auto_scheduler.FuseStep(0x7f1c58062ab8)
# auto_scheduler.SplitStep(0x7f1c5803dd98)
# auto_scheduler.AnnotationStep(0x7f1c58019ae8)
# auto_scheduler.AnnotationStep(0x7f1c58005b28)
# auto_scheduler.FuseStep(0x7f1c580a02e8)
# auto_scheduler.SplitStep(0x7f1c58026e18)
# auto_scheduler.AnnotationStep(0x7f1c58078228)
# auto_scheduler.AnnotationStep(0x7f1c58074188)
# auto_scheduler.FuseStep(0x7f1c580cf968)
# auto_scheduler.AnnotationStep(0x7f1c5802d5f8)
# auto_scheduler.FuseStep(0x7f1c58083e98)
# auto_scheduler.AnnotationStep(0x7f1c58016748)
# auto_scheduler.FuseStep(0x7f1c58098628)
# auto_scheduler.AnnotationStep(0x7f1c58059098)
# auto_scheduler.FuseStep(0x7f1c58061ac8)
# auto_scheduler.SplitStep(0x7f1c5800dff8)
# auto_scheduler.AnnotationStep(0x7f1c5802a578)
# auto_scheduler.FollowFusedSplitStep(0x7f1c580028d8)
# auto_scheduler.AnnotationStep(0x7f1c58026758)
# auto_scheduler.FuseStep(0x7f1c5807e7c8)
# auto_scheduler.SplitStep(0x7f1c5808fd78)
# auto_scheduler.AnnotationStep(0x7f1c58065648)
# auto_scheduler.FollowFusedSplitStep(0x7f1c5805d498)
# auto_scheduler.AnnotationStep(0x7f1c58055a58)
# auto_scheduler.FuseStep(0x7f1c580269e8)
# auto_scheduler.SplitStep(0x7f1c5801cc78)
# auto_scheduler.AnnotationStep(0x7f1c58054858)
# auto_scheduler.AnnotationStep(0x7f1c580317f8)
# auto_scheduler.PragmaStep(0x7f1c5801d5e8)
# auto_scheduler.PragmaStep(0x7f1c58054948)
# auto_scheduler.PragmaStep(0x7f1c58013378)
# ================================================================================
# Placeholder: p0, p1, p2
# data_pack auto_unroll: 512
# blockIdx.x p.0@ci.0@p.1@ci.1@.0 (0,392)
#   threadIdx.x p.0@ci.0@p.1@ci.1@.1 (0,32)
#     for eps (0,4)
#       for nu (0,4)
#         for p (blockIdx_x // 8,1)
#           for ci (blockIdx_x % 8 * 32 + threadIdx_x,1)
#             input_tile = ...
#     unroll eps (0,4)
#       unroll nu (0,4)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             data_pack = ...
# blockIdx.x eps.0@nu.0@p.0@co.0@ (0,32)
#   vthread eps.1@nu.1@p.1@co.1@ (0,1)
#     threadIdx.x eps.2@nu.2@p.2@co.2@ (0,32)
#       bgemm.local auto_unroll: 16
#       for eps_c.0 (0,1)
#         for nu_c.0 (0,1)
#           for p_c.0 (0,1)
#             for co_c.0 (0,1)
#               for eps_c.1 (0,1)
#                 for nu_c.1 (0,1)
#                   for p_c.1 (0,1)
#                     for co_c.1 (0,1)
#                       for eps_c.2 (0,1)
#                         for nu_c.2 (0,1)
#                           for p_c.2 (0,1)
#                             for co_c.2 (0,1)
#                               for ci.0 (0,16)
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,64)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       p1.shared = ...
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,98)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       data_pack.shared = ...
#                                 for ci.1 (0,4)
#                                   for eps_c.3 (0,2)
#                                     for nu_c.3 (0,1)
#                                       for p_c.3 (0,49)
#                                         for co_c.3 (0,1)
#                                           for ci.2 (0,4)
#                                             for eps_c.4 (0,1)
#                                               for nu_c.4 (0,1)
#                                                 for p_c.4 (0,1)
#                                                   for co_c.4 (0,2)
#                                                     bgemm.local = ...
#       for eps.3 (0,2)
#         for nu.3 (0,1)
#           for p.3 (0,49)
#             for co.3 (0,2)
#               bgemm = ...
# inverse auto_unroll: 64
# blockIdx.x p.0@co.0@p.1@co.1@.0 (0,392)
#   threadIdx.x p.0@co.0@p.1@co.1@.1 (0,32)
#     unroll vh (0,2)
#       unroll vw (0,2)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             inverse = ...
# blockIdx.x ax0@ax1@ax2@ax3@.0 (0,1568)
#   threadIdx.x ax0@ax1@ax2@ax3@.1 (0,32)
#     T_relu = ...

# %%
print(tasks[10].desc)
print(tasks[10].compute_dag.init_state)
print("="*80)
for i, step in enumerate(s.transform_steps):
    print(f"Step {i} : {step}")
    partial_state = tvm._ffi.get_global_func("auto_scheduler.ReplayStepsPartial")(tasks[10].compute_dag, s, i)
    print(partial_state)
    print("="*80)
# Out:
# vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_2
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# for vh (0,2)
#   for vw (0,2)
#     for p (0,49)
#       for co (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             inverse = ...
# for n (0,1)
#   for h (0,14)
#     for w (0,14)
#       for co (0,256)
#         conv2d_winograd = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_add = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 0 : auto_scheduler.ComputeInlineStep(0x3c4ec098)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# for vh (0,2)
#   for vw (0,2)
#     for p (0,49)
#       for co (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             inverse = ...
# for n (0,1)
#   for h (0,14)
#     for w (0,14)
#       for co (0,256)
#         conv2d_winograd = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_add = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 1 : auto_scheduler.ComputeInlineStep(0x3ddd1278)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# for vh (0,2)
#   for vw (0,2)
#     for p (0,49)
#       for co (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             inverse = ...
# for n (0,1)
#   for h (0,14)
#     for w (0,14)
#       for co (0,256)
#         conv2d_winograd = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 2 : auto_scheduler.AnnotationStep(0x3deb4a08)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# for vh (0,2)
#   for vw (0,2)
#     for p (0,49)
#       for co (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 3 : auto_scheduler.AnnotationStep(0x3caf0c38)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# unroll vh (0,2)
#   for vw (0,2)
#     for p (0,49)
#       for co (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 4 : auto_scheduler.SplitStep(0x7f1c58090258)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# unroll vh (0,2)
#   unroll vw (0,2)
#     for p (0,49)
#       for co (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 5 : auto_scheduler.SplitStep(0x7f1c580d1d58)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# unroll vh (0,2)
#   unroll vw (0,2)
#     for p.0 (0,7)
#       for p.1 (0,7)
#         for co (0,256)
#           for r_a (0,4)
#             for r_b (0,4)
#               inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 6 : auto_scheduler.AnnotationStep(0x3df78598)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# unroll vh (0,2)
#   unroll vw (0,2)
#     for p.0 (0,7)
#       for p.1 (0,7)
#         for co.0 (0,128)
#           for co.1 (0,2)
#             for r_a (0,4)
#               for r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 7 : auto_scheduler.AnnotationStep(0x3db9e378)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# unroll vh (0,2)
#   unroll vw (0,2)
#     for p.0 (0,7)
#       for p.1 (0,7)
#         for co.0 (0,128)
#           for co.1 (0,2)
#             unroll r_a (0,4)
#               for r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 8 : auto_scheduler.ReorderStep(0x3c502518)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# unroll vh (0,2)
#   unroll vw (0,2)
#     for p.0 (0,7)
#       for p.1 (0,7)
#         for co.0 (0,128)
#           for co.1 (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 9 : auto_scheduler.ComputeInlineStep(0x3e260758)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 10 : auto_scheduler.CacheWriteStep(0x3daea5e8)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 11 : auto_scheduler.SplitStep(0x7f1c5805f8a8)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c (0,4)
#   for nu_c (0,4)
#     for p_c (0,49)
#       for co_c (0,256)
#         for ci (0,256)
#           bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 12 : auto_scheduler.SplitStep(0x7f1c58118848)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for eps_c.1 (0,1)
#     for eps_c.2 (0,2)
#       for eps_c.3 (0,2)
#         for eps_c.4 (0,1)
#           for nu_c (0,4)
#             for p_c (0,49)
#               for co_c (0,256)
#                 for ci (0,256)
#                   bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 13 : auto_scheduler.SplitStep(0x7f1c58041ef8)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for eps_c.1 (0,1)
#     for eps_c.2 (0,2)
#       for eps_c.3 (0,2)
#         for eps_c.4 (0,1)
#           for nu_c.0 (0,4)
#             for nu_c.1 (0,1)
#               for nu_c.2 (0,1)
#                 for nu_c.3 (0,1)
#                   for nu_c.4 (0,1)
#                     for p_c (0,49)
#                       for co_c (0,256)
#                         for ci (0,256)
#                           bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 14 : auto_scheduler.SplitStep(0x7f1c5804a9f8)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for eps_c.1 (0,1)
#     for eps_c.2 (0,2)
#       for eps_c.3 (0,2)
#         for eps_c.4 (0,1)
#           for nu_c.0 (0,4)
#             for nu_c.1 (0,1)
#               for nu_c.2 (0,1)
#                 for nu_c.3 (0,1)
#                   for nu_c.4 (0,1)
#                     for p_c.0 (0,1)
#                       for p_c.1 (0,1)
#                         for p_c.2 (0,1)
#                           for p_c.3 (0,49)
#                             for p_c.4 (0,1)
#                               for co_c (0,256)
#                                 for ci (0,256)
#                                   bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 15 : auto_scheduler.SplitStep(0x7f1c580b6ac8)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for eps_c.1 (0,1)
#     for eps_c.2 (0,2)
#       for eps_c.3 (0,2)
#         for eps_c.4 (0,1)
#           for nu_c.0 (0,4)
#             for nu_c.1 (0,1)
#               for nu_c.2 (0,1)
#                 for nu_c.3 (0,1)
#                   for nu_c.4 (0,1)
#                     for p_c.0 (0,1)
#                       for p_c.1 (0,1)
#                         for p_c.2 (0,1)
#                           for p_c.3 (0,49)
#                             for p_c.4 (0,1)
#                               for co_c.0 (0,8)
#                                 for co_c.1 (0,1)
#                                   for co_c.2 (0,16)
#                                     for co_c.3 (0,1)
#                                       for co_c.4 (0,2)
#                                         for ci (0,256)
#                                           bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 16 : auto_scheduler.ReorderStep(0x3d5804f8)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for eps_c.1 (0,1)
#     for eps_c.2 (0,2)
#       for eps_c.3 (0,2)
#         for eps_c.4 (0,1)
#           for nu_c.0 (0,4)
#             for nu_c.1 (0,1)
#               for nu_c.2 (0,1)
#                 for nu_c.3 (0,1)
#                   for nu_c.4 (0,1)
#                     for p_c.0 (0,1)
#                       for p_c.1 (0,1)
#                         for p_c.2 (0,1)
#                           for p_c.3 (0,49)
#                             for p_c.4 (0,1)
#                               for co_c.0 (0,8)
#                                 for co_c.1 (0,1)
#                                   for co_c.2 (0,16)
#                                     for co_c.3 (0,1)
#                                       for co_c.4 (0,2)
#                                         for ci.0 (0,16)
#                                           for ci.1 (0,4)
#                                             for ci.2 (0,4)
#                                               bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 17 : auto_scheduler.FollowSplitStep(0x3df10d68)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for nu_c.0 (0,4)
#     for p_c.0 (0,1)
#       for co_c.0 (0,8)
#         for eps_c.1 (0,1)
#           for nu_c.1 (0,1)
#             for p_c.1 (0,1)
#               for co_c.1 (0,1)
#                 for eps_c.2 (0,2)
#                   for nu_c.2 (0,1)
#                     for p_c.2 (0,1)
#                       for co_c.2 (0,16)
#                         for ci.0 (0,16)
#                           for ci.1 (0,4)
#                             for eps_c.3 (0,2)
#                               for nu_c.3 (0,1)
#                                 for p_c.3 (0,49)
#                                   for co_c.3 (0,1)
#                                     for ci.2 (0,4)
#                                       for eps_c.4 (0,1)
#                                         for nu_c.4 (0,1)
#                                           for p_c.4 (0,1)
#                                             for co_c.4 (0,2)
#                                               bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 18 : auto_scheduler.FollowSplitStep(0x3d5e8888)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for nu_c.0 (0,4)
#     for p_c.0 (0,1)
#       for co_c.0 (0,8)
#         for eps_c.1 (0,1)
#           for nu_c.1 (0,1)
#             for p_c.1 (0,1)
#               for co_c.1 (0,1)
#                 for eps_c.2 (0,2)
#                   for nu_c.2 (0,1)
#                     for p_c.2 (0,1)
#                       for co_c.2 (0,16)
#                         for ci.0 (0,16)
#                           for ci.1 (0,4)
#                             for eps_c.3 (0,2)
#                               for nu_c.3 (0,1)
#                                 for p_c.3 (0,49)
#                                   for co_c.3 (0,1)
#                                     for ci.2 (0,4)
#                                       for eps_c.4 (0,1)
#                                         for nu_c.4 (0,1)
#                                           for p_c.4 (0,1)
#                                             for co_c.4 (0,2)
#                                               bgemm.local = ...
# for eps.0 (0,1)
#   for eps.1 (0,1)
#     for eps.2 (0,2)
#       for eps.3 (0,2)
#         for nu (0,4)
#           for p (0,49)
#             for co (0,256)
#               bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 19 : auto_scheduler.FollowSplitStep(0x3dea1508)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for nu_c.0 (0,4)
#     for p_c.0 (0,1)
#       for co_c.0 (0,8)
#         for eps_c.1 (0,1)
#           for nu_c.1 (0,1)
#             for p_c.1 (0,1)
#               for co_c.1 (0,1)
#                 for eps_c.2 (0,2)
#                   for nu_c.2 (0,1)
#                     for p_c.2 (0,1)
#                       for co_c.2 (0,16)
#                         for ci.0 (0,16)
#                           for ci.1 (0,4)
#                             for eps_c.3 (0,2)
#                               for nu_c.3 (0,1)
#                                 for p_c.3 (0,49)
#                                   for co_c.3 (0,1)
#                                     for ci.2 (0,4)
#                                       for eps_c.4 (0,1)
#                                         for nu_c.4 (0,1)
#                                           for p_c.4 (0,1)
#                                             for co_c.4 (0,2)
#                                               bgemm.local = ...
# for eps.0 (0,1)
#   for eps.1 (0,1)
#     for eps.2 (0,2)
#       for eps.3 (0,2)
#         for nu.0 (0,4)
#           for nu.1 (0,1)
#             for nu.2 (0,1)
#               for nu.3 (0,1)
#                 for p (0,49)
#                   for co (0,256)
#                     bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 20 : auto_scheduler.FollowSplitStep(0x3c8e61d8)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for nu_c.0 (0,4)
#     for p_c.0 (0,1)
#       for co_c.0 (0,8)
#         for eps_c.1 (0,1)
#           for nu_c.1 (0,1)
#             for p_c.1 (0,1)
#               for co_c.1 (0,1)
#                 for eps_c.2 (0,2)
#                   for nu_c.2 (0,1)
#                     for p_c.2 (0,1)
#                       for co_c.2 (0,16)
#                         for ci.0 (0,16)
#                           for ci.1 (0,4)
#                             for eps_c.3 (0,2)
#                               for nu_c.3 (0,1)
#                                 for p_c.3 (0,49)
#                                   for co_c.3 (0,1)
#                                     for ci.2 (0,4)
#                                       for eps_c.4 (0,1)
#                                         for nu_c.4 (0,1)
#                                           for p_c.4 (0,1)
#                                             for co_c.4 (0,2)
#                                               bgemm.local = ...
# for eps.0 (0,1)
#   for eps.1 (0,1)
#     for eps.2 (0,2)
#       for eps.3 (0,2)
#         for nu.0 (0,4)
#           for nu.1 (0,1)
#             for nu.2 (0,1)
#               for nu.3 (0,1)
#                 for p.0 (0,1)
#                   for p.1 (0,1)
#                     for p.2 (0,1)
#                       for p.3 (0,49)
#                         for co (0,256)
#                           bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 21 : auto_scheduler.ReorderStep(0x3e3bde78)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for nu_c.0 (0,4)
#     for p_c.0 (0,1)
#       for co_c.0 (0,8)
#         for eps_c.1 (0,1)
#           for nu_c.1 (0,1)
#             for p_c.1 (0,1)
#               for co_c.1 (0,1)
#                 for eps_c.2 (0,2)
#                   for nu_c.2 (0,1)
#                     for p_c.2 (0,1)
#                       for co_c.2 (0,16)
#                         for ci.0 (0,16)
#                           for ci.1 (0,4)
#                             for eps_c.3 (0,2)
#                               for nu_c.3 (0,1)
#                                 for p_c.3 (0,49)
#                                   for co_c.3 (0,1)
#                                     for ci.2 (0,4)
#                                       for eps_c.4 (0,1)
#                                         for nu_c.4 (0,1)
#                                           for p_c.4 (0,1)
#                                             for co_c.4 (0,2)
#                                               bgemm.local = ...
# for eps.0 (0,1)
#   for eps.1 (0,1)
#     for eps.2 (0,2)
#       for eps.3 (0,2)
#         for nu.0 (0,4)
#           for nu.1 (0,1)
#             for nu.2 (0,1)
#               for nu.3 (0,1)
#                 for p.0 (0,1)
#                   for p.1 (0,1)
#                     for p.2 (0,1)
#                       for p.3 (0,49)
#                         for co.0 (0,8)
#                           for co.1 (0,1)
#                             for co.2 (0,16)
#                               for co.3 (0,2)
#                                 bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 22 : auto_scheduler.ComputeAtStep(0x3df83878)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for nu_c.0 (0,4)
#     for p_c.0 (0,1)
#       for co_c.0 (0,8)
#         for eps_c.1 (0,1)
#           for nu_c.1 (0,1)
#             for p_c.1 (0,1)
#               for co_c.1 (0,1)
#                 for eps_c.2 (0,2)
#                   for nu_c.2 (0,1)
#                     for p_c.2 (0,1)
#                       for co_c.2 (0,16)
#                         for ci.0 (0,16)
#                           for ci.1 (0,4)
#                             for eps_c.3 (0,2)
#                               for nu_c.3 (0,1)
#                                 for p_c.3 (0,49)
#                                   for co_c.3 (0,1)
#                                     for ci.2 (0,4)
#                                       for eps_c.4 (0,1)
#                                         for nu_c.4 (0,1)
#                                           for p_c.4 (0,1)
#                                             for co_c.4 (0,2)
#                                               bgemm.local = ...
# for eps.0 (0,1)
#   for nu.0 (0,4)
#     for p.0 (0,1)
#       for co.0 (0,8)
#         for eps.1 (0,1)
#           for nu.1 (0,1)
#             for p.1 (0,1)
#               for co.1 (0,1)
#                 for eps.2 (0,2)
#                   for nu.2 (0,1)
#                     for p.2 (0,1)
#                       for co.2 (0,16)
#                         for eps.3 (0,2)
#                           for nu.3 (0,1)
#                             for p.3 (0,49)
#                               for co.3 (0,2)
#                                 bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 23 : auto_scheduler.CacheReadStep(0x3c9dba38)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps.0 (0,1)
#   for nu.0 (0,4)
#     for p.0 (0,1)
#       for co.0 (0,8)
#         for eps.1 (0,1)
#           for nu.1 (0,1)
#             for p.1 (0,1)
#               for co.1 (0,1)
#                 for eps.2 (0,2)
#                   for nu.2 (0,1)
#                     for p.2 (0,1)
#                       for co.2 (0,16)
#                         for eps_c.0 (0,1)
#                           for nu_c.0 (0,1)
#                             for p_c.0 (0,1)
#                               for co_c.0 (0,1)
#                                 for eps_c.1 (0,1)
#                                   for nu_c.1 (0,1)
#                                     for p_c.1 (0,1)
#                                       for co_c.1 (0,1)
#                                         for eps_c.2 (0,1)
#                                           for nu_c.2 (0,1)
#                                             for p_c.2 (0,1)
#                                               for co_c.2 (0,1)
#                                                 for ci.0 (0,16)
#                                                   for ci.1 (0,4)
#                                                     for eps_c.3 (0,2)
#                                                       for nu_c.3 (0,1)
#                                                         for p_c.3 (0,49)
#                                                           for co_c.3 (0,1)
#                                                             for ci.2 (0,4)
#                                                               for eps_c.4 (0,1)
#                                                                 for nu_c.4 (0,1)
#                                                                   for p_c.4 (0,1)
#                                                                     for co_c.4 (0,2)
#                                                                       bgemm.local = ...
#                         for eps.3 (0,2)
#                           for nu.3 (0,1)
#                             for p.3 (0,49)
#                               for co.3 (0,2)
#                                 bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 24 : auto_scheduler.ComputeAtStep(0x3d562048)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for ax0 (0,4)
#   for ax1 (0,4)
#     for ax2 (0,256)
#       for ax3 (0,256)
#         p1.shared = ...
# for eps.0 (0,1)
#   for nu.0 (0,4)
#     for p.0 (0,1)
#       for co.0 (0,8)
#         for eps.1 (0,1)
#           for nu.1 (0,1)
#             for p.1 (0,1)
#               for co.1 (0,1)
#                 for eps.2 (0,2)
#                   for nu.2 (0,1)
#                     for p.2 (0,1)
#                       for co.2 (0,16)
#                         for eps_c.0 (0,1)
#                           for nu_c.0 (0,1)
#                             for p_c.0 (0,1)
#                               for co_c.0 (0,1)
#                                 for eps_c.1 (0,1)
#                                   for nu_c.1 (0,1)
#                                     for p_c.1 (0,1)
#                                       for co_c.1 (0,1)
#                                         for eps_c.2 (0,1)
#                                           for nu_c.2 (0,1)
#                                             for p_c.2 (0,1)
#                                               for co_c.2 (0,1)
#                                                 for ci.0 (0,16)
#                                                   for ci.1 (0,4)
#                                                     for eps_c.3 (0,2)
#                                                       for nu_c.3 (0,1)
#                                                         for p_c.3 (0,49)
#                                                           for co_c.3 (0,1)
#                                                             for ci.2 (0,4)
#                                                               for eps_c.4 (0,1)
#                                                                 for nu_c.4 (0,1)
#                                                                   for p_c.4 (0,1)
#                                                                     for co_c.4 (0,2)
#                                                                       bgemm.local = ...
#                         for eps.3 (0,2)
#                           for nu.3 (0,1)
#                             for p.3 (0,49)
#                               for co.3 (0,2)
#                                 bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 25 : auto_scheduler.CacheReadStep(0x3db9d4d8)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps.0 (0,1)
#   for nu.0 (0,4)
#     for p.0 (0,1)
#       for co.0 (0,8)
#         for eps.1 (0,1)
#           for nu.1 (0,1)
#             for p.1 (0,1)
#               for co.1 (0,1)
#                 for eps.2 (0,2)
#                   for nu.2 (0,1)
#                     for p.2 (0,1)
#                       for co.2 (0,16)
#                         for eps_c.0 (0,1)
#                           for nu_c.0 (0,1)
#                             for p_c.0 (0,1)
#                               for co_c.0 (0,1)
#                                 for eps_c.1 (0,1)
#                                   for nu_c.1 (0,1)
#                                     for p_c.1 (0,1)
#                                       for co_c.1 (0,1)
#                                         for eps_c.2 (0,1)
#                                           for nu_c.2 (0,1)
#                                             for p_c.2 (0,1)
#                                               for co_c.2 (0,1)
#                                                 for ci.0 (0,16)
#                                                   for ax0 (eps_outer_inner * 2,2)
#                                                     for ax1 (nu_outer_outer_outer,1)
#                                                       for ax2 (co_outer_outer_outer * 32 + co_outer_inner * 2,2)
#                                                         for ax3 (ci_outer_outer * 16,16)
#                                                           p1.shared = ...
#                                                   for ci.1 (0,4)
#                                                     for eps_c.3 (0,2)
#                                                       for nu_c.3 (0,1)
#                                                         for p_c.3 (0,49)
#                                                           for co_c.3 (0,1)
#                                                             for ci.2 (0,4)
#                                                               for eps_c.4 (0,1)
#                                                                 for nu_c.4 (0,1)
#                                                                   for p_c.4 (0,1)
#                                                                     for co_c.4 (0,2)
#                                                                       bgemm.local = ...
#                         for eps.3 (0,2)
#                           for nu.3 (0,1)
#                             for p.3 (0,49)
#                               for co.3 (0,2)
#                                 bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 26 : auto_scheduler.ComputeAtStep(0x3deb4998)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for ax0 (0,4)
#   for ax1 (0,4)
#     for ax2 (0,49)
#       for ax3 (0,256)
#         data_pack.shared = ...
# for eps.0 (0,1)
#   for nu.0 (0,4)
#     for p.0 (0,1)
#       for co.0 (0,8)
#         for eps.1 (0,1)
#           for nu.1 (0,1)
#             for p.1 (0,1)
#               for co.1 (0,1)
#                 for eps.2 (0,2)
#                   for nu.2 (0,1)
#                     for p.2 (0,1)
#                       for co.2 (0,16)
#                         for eps_c.0 (0,1)
#                           for nu_c.0 (0,1)
#                             for p_c.0 (0,1)
#                               for co_c.0 (0,1)
#                                 for eps_c.1 (0,1)
#                                   for nu_c.1 (0,1)
#                                     for p_c.1 (0,1)
#                                       for co_c.1 (0,1)
#                                         for eps_c.2 (0,1)
#                                           for nu_c.2 (0,1)
#                                             for p_c.2 (0,1)
#                                               for co_c.2 (0,1)
#                                                 for ci.0 (0,16)
#                                                   for ax0 (eps_outer_inner * 2,2)
#                                                     for ax1 (nu_outer_outer_outer,1)
#                                                       for ax2 (co_outer_outer_outer * 32 + co_outer_inner * 2,2)
#                                                         for ax3 (ci_outer_outer * 16,16)
#                                                           p1.shared = ...
#                                                   for ci.1 (0,4)
#                                                     for eps_c.3 (0,2)
#                                                       for nu_c.3 (0,1)
#                                                         for p_c.3 (0,49)
#                                                           for co_c.3 (0,1)
#                                                             for ci.2 (0,4)
#                                                               for eps_c.4 (0,1)
#                                                                 for nu_c.4 (0,1)
#                                                                   for p_c.4 (0,1)
#                                                                     for co_c.4 (0,2)
#                                                                       bgemm.local = ...
#                         for eps.3 (0,2)
#                           for nu.3 (0,1)
#                             for p.3 (0,49)
#                               for co.3 (0,2)
#                                 bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# ================================================================================
# Step 27 : auto_scheduler.AnnotationStep(0x3dec3128)
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps.0 (0,1)
#   for nu.0 (0,4)
#     for p.0 (0,1)
#       for co.0 (0,8)
#         for eps.1 (0,1)
#           for nu.1 (0,1)
#             for p.1 (0,1)
#               for co.1 (0,1)
#                 for eps.2 (0,2)
#                   for nu.2 (0,1)
#                     for p.2 (0,1)
#                       for co.2 (0,16)
#                         for eps_c.0 (0,1)
#                           for nu_c.0 (0,1)
#                             for p_c.0 (0,1)
#                               for co_c.0 (0,1)
#                                 for eps_c.1 (0,1)
#                                   for nu_c.1 (0,1)
#                                     for p_c.1 (0,1)
#                                       for co_c.1 (0,1)
#                                         for eps_c.2 (0,1)
#                                           for nu_c.2 (0,1)
#                                             for p_c.2 (0,1)
#                                               for co_c.2 (0,1)
#                                                 for ci.0 (0,16)
#                                                   for ax0 (eps_outer_inner * 2,2)
#                                                     for ax1 (nu_outer_outer_outer,1)
#                                                       for ax2 (co_outer_outer_outer * 32 + co_outer_inner * 2,2)
#                                                         for ax3 (ci_outer_outer * 16,16)
#                                                           p1.shared = ...
#                                                   for ax0 (eps_outer_inner * 2,2)
#                                                     for ax1 (nu_outer_outer_outer,1)
#                                                       for ax2 (0,49)
#                                                         for ax3 (ci_outer_outer * 16,16)
#                                                           data_pack.shared = ...
#                                                   for ci.1 (0,4)
# ...
# blockIdx.x eps.0@nu.0@p.0@co.0@ (0,32)
#   vthread eps.1@nu.1@p.1@co.1@ (0,1)
#     threadIdx.x eps.2@nu.2@p.2@co.2@ (0,32)
#       for eps_c.0 (0,1)
#         for nu_c.0 (0,1)
#           for p_c.0 (0,1)
#             for co_c.0 (0,1)
#               for eps_c.1 (0,1)
#                 for nu_c.1 (0,1)
#                   for p_c.1 (0,1)
#                     for co_c.1 (0,1)
#                       for eps_c.2 (0,1)
#                         for nu_c.2 (0,1)
#                           for p_c.2 (0,1)
#                             for co_c.2 (0,1)
#                               for ci.0 (0,16)
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,64)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       p1.shared = ...
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,98)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       data_pack.shared = ...
#                                 for ci.1 (0,4)
#                                   for eps_c.3 (0,2)
#                                     for nu_c.3 (0,1)
#                                       for p_c.3 (0,49)
#                                         for co_c.3 (0,1)
#                                           for ci.2 (0,4)
#                                             for eps_c.4 (0,1)
#                                               for nu_c.4 (0,1)
#                                                 for p_c.4 (0,1)
#                                                   for co_c.4 (0,2)
#                                                     bgemm.local = ...
#       for eps.3 (0,2)
#         for nu.3 (0,1)
#           for p.3 (0,49)
#             for co.3 (0,2)
#               bgemm = ...
# blockIdx.x p.0@co.0@p.1@co.1@.0 (0,392)
#   threadIdx.x p.0@co.0@p.1@co.1@.1 (0,32)
#     unroll vh (0,2)
#       unroll vw (0,2)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             inverse = ...
# blockIdx.x ax0@ax1@ax2@ax3@.0 (0,1568)
#   threadIdx.x ax0@ax1@ax2@ax3@.1 (0,32)
#     T_relu = ...
#
# ================================================================================
# Step 63 : auto_scheduler.AnnotationStep(0x7f1c58054858)
# Placeholder: p0, p1, p2
# for p.0@ci.0@p.1@ci.1@.0 (0,392)
#   for p.0@ci.0@p.1@ci.1@.1 (0,32)
#     for eps (0,4)
#       for nu (0,4)
#         for p (p_outer_ci_outer_fused_p_inner_fused_ci_inner_fused_outer // 8,1)
#           for ci (p_outer_ci_outer_fused_p_inner_fused_ci_inner_fused_outer % 8 * 32 + p_outer_ci_outer_fused_p_inner_fused_ci_inner_fused_inner,1)
#             input_tile = ...
#     unroll eps (0,4)
#       unroll nu (0,4)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             data_pack = ...
# blockIdx.x eps.0@nu.0@p.0@co.0@ (0,32)
#   vthread eps.1@nu.1@p.1@co.1@ (0,1)
#     threadIdx.x eps.2@nu.2@p.2@co.2@ (0,32)
#       for eps_c.0 (0,1)
#         for nu_c.0 (0,1)
#           for p_c.0 (0,1)
#             for co_c.0 (0,1)
#               for eps_c.1 (0,1)
#                 for nu_c.1 (0,1)
#                   for p_c.1 (0,1)
#                     for co_c.1 (0,1)
#                       for eps_c.2 (0,1)
#                         for nu_c.2 (0,1)
#                           for p_c.2 (0,1)
#                             for co_c.2 (0,1)
#                               for ci.0 (0,16)
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,64)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       p1.shared = ...
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,98)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       data_pack.shared = ...
#                                 for ci.1 (0,4)
#                                   for eps_c.3 (0,2)
#                                     for nu_c.3 (0,1)
#                                       for p_c.3 (0,49)
#                                         for co_c.3 (0,1)
#                                           for ci.2 (0,4)
#                                             for eps_c.4 (0,1)
#                                               for nu_c.4 (0,1)
#                                                 for p_c.4 (0,1)
#                                                   for co_c.4 (0,2)
#                                                     bgemm.local = ...
#       for eps.3 (0,2)
#         for nu.3 (0,1)
#           for p.3 (0,49)
#             for co.3 (0,2)
#               bgemm = ...
# blockIdx.x p.0@co.0@p.1@co.1@.0 (0,392)
#   threadIdx.x p.0@co.0@p.1@co.1@.1 (0,32)
#     unroll vh (0,2)
#       unroll vw (0,2)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             inverse = ...
# blockIdx.x ax0@ax1@ax2@ax3@.0 (0,1568)
#   threadIdx.x ax0@ax1@ax2@ax3@.1 (0,32)
#     T_relu = ...
#
# ================================================================================
# Step 64 : auto_scheduler.AnnotationStep(0x7f1c580317f8)
# Placeholder: p0, p1, p2
# blockIdx.x p.0@ci.0@p.1@ci.1@.0 (0,392)
#   for p.0@ci.0@p.1@ci.1@.1 (0,32)
#     for eps (0,4)
#       for nu (0,4)
#         for p (blockIdx_x // 8,1)
#           for ci (blockIdx_x % 8 * 32 + p_outer_ci_outer_fused_p_inner_fused_ci_inner_fused_inner,1)
#             input_tile = ...
#     unroll eps (0,4)
#       unroll nu (0,4)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             data_pack = ...
# blockIdx.x eps.0@nu.0@p.0@co.0@ (0,32)
#   vthread eps.1@nu.1@p.1@co.1@ (0,1)
#     threadIdx.x eps.2@nu.2@p.2@co.2@ (0,32)
#       for eps_c.0 (0,1)
#         for nu_c.0 (0,1)
#           for p_c.0 (0,1)
#             for co_c.0 (0,1)
#               for eps_c.1 (0,1)
#                 for nu_c.1 (0,1)
#                   for p_c.1 (0,1)
#                     for co_c.1 (0,1)
#                       for eps_c.2 (0,1)
#                         for nu_c.2 (0,1)
#                           for p_c.2 (0,1)
#                             for co_c.2 (0,1)
#                               for ci.0 (0,16)
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,64)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       p1.shared = ...
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,98)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       data_pack.shared = ...
#                                 for ci.1 (0,4)
#                                   for eps_c.3 (0,2)
#                                     for nu_c.3 (0,1)
#                                       for p_c.3 (0,49)
#                                         for co_c.3 (0,1)
#                                           for ci.2 (0,4)
#                                             for eps_c.4 (0,1)
#                                               for nu_c.4 (0,1)
#                                                 for p_c.4 (0,1)
#                                                   for co_c.4 (0,2)
#                                                     bgemm.local = ...
#       for eps.3 (0,2)
#         for nu.3 (0,1)
#           for p.3 (0,49)
#             for co.3 (0,2)
#               bgemm = ...
# blockIdx.x p.0@co.0@p.1@co.1@.0 (0,392)
#   threadIdx.x p.0@co.0@p.1@co.1@.1 (0,32)
#     unroll vh (0,2)
#       unroll vw (0,2)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             inverse = ...
# blockIdx.x ax0@ax1@ax2@ax3@.0 (0,1568)
#   threadIdx.x ax0@ax1@ax2@ax3@.1 (0,32)
#     T_relu = ...
#
# ================================================================================
# Step 65 : auto_scheduler.PragmaStep(0x7f1c5801d5e8)
# Placeholder: p0, p1, p2
# blockIdx.x p.0@ci.0@p.1@ci.1@.0 (0,392)
#   threadIdx.x p.0@ci.0@p.1@ci.1@.1 (0,32)
#     for eps (0,4)
#       for nu (0,4)
#         for p (blockIdx_x // 8,1)
#           for ci (blockIdx_x % 8 * 32 + threadIdx_x,1)
#             input_tile = ...
#     unroll eps (0,4)
#       unroll nu (0,4)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             data_pack = ...
# blockIdx.x eps.0@nu.0@p.0@co.0@ (0,32)
#   vthread eps.1@nu.1@p.1@co.1@ (0,1)
#     threadIdx.x eps.2@nu.2@p.2@co.2@ (0,32)
#       for eps_c.0 (0,1)
#         for nu_c.0 (0,1)
#           for p_c.0 (0,1)
#             for co_c.0 (0,1)
#               for eps_c.1 (0,1)
#                 for nu_c.1 (0,1)
#                   for p_c.1 (0,1)
#                     for co_c.1 (0,1)
#                       for eps_c.2 (0,1)
#                         for nu_c.2 (0,1)
#                           for p_c.2 (0,1)
#                             for co_c.2 (0,1)
#                               for ci.0 (0,16)
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,64)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       p1.shared = ...
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,98)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       data_pack.shared = ...
#                                 for ci.1 (0,4)
#                                   for eps_c.3 (0,2)
#                                     for nu_c.3 (0,1)
#                                       for p_c.3 (0,49)
#                                         for co_c.3 (0,1)
#                                           for ci.2 (0,4)
#                                             for eps_c.4 (0,1)
#                                               for nu_c.4 (0,1)
#                                                 for p_c.4 (0,1)
#                                                   for co_c.4 (0,2)
#                                                     bgemm.local = ...
#       for eps.3 (0,2)
#         for nu.3 (0,1)
#           for p.3 (0,49)
#             for co.3 (0,2)
#               bgemm = ...
# blockIdx.x p.0@co.0@p.1@co.1@.0 (0,392)
#   threadIdx.x p.0@co.0@p.1@co.1@.1 (0,32)
#     unroll vh (0,2)
#       unroll vw (0,2)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             inverse = ...
# blockIdx.x ax0@ax1@ax2@ax3@.0 (0,1568)
#   threadIdx.x ax0@ax1@ax2@ax3@.1 (0,32)
#     T_relu = ...
#
# ================================================================================
# Step 66 : auto_scheduler.PragmaStep(0x7f1c58054948)
# Placeholder: p0, p1, p2
# data_pack auto_unroll: 512
# blockIdx.x p.0@ci.0@p.1@ci.1@.0 (0,392)
#   threadIdx.x p.0@ci.0@p.1@ci.1@.1 (0,32)
#     for eps (0,4)
#       for nu (0,4)
#         for p (blockIdx_x // 8,1)
#           for ci (blockIdx_x % 8 * 32 + threadIdx_x,1)
#             input_tile = ...
#     unroll eps (0,4)
#       unroll nu (0,4)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             data_pack = ...
# blockIdx.x eps.0@nu.0@p.0@co.0@ (0,32)
#   vthread eps.1@nu.1@p.1@co.1@ (0,1)
#     threadIdx.x eps.2@nu.2@p.2@co.2@ (0,32)
#       for eps_c.0 (0,1)
#         for nu_c.0 (0,1)
#           for p_c.0 (0,1)
#             for co_c.0 (0,1)
#               for eps_c.1 (0,1)
#                 for nu_c.1 (0,1)
#                   for p_c.1 (0,1)
#                     for co_c.1 (0,1)
#                       for eps_c.2 (0,1)
#                         for nu_c.2 (0,1)
#                           for p_c.2 (0,1)
#                             for co_c.2 (0,1)
#                               for ci.0 (0,16)
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,64)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       p1.shared = ...
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,98)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       data_pack.shared = ...
#                                 for ci.1 (0,4)
#                                   for eps_c.3 (0,2)
#                                     for nu_c.3 (0,1)
#                                       for p_c.3 (0,49)
#                                         for co_c.3 (0,1)
#                                           for ci.2 (0,4)
#                                             for eps_c.4 (0,1)
#                                               for nu_c.4 (0,1)
#                                                 for p_c.4 (0,1)
#                                                   for co_c.4 (0,2)
#                                                     bgemm.local = ...
#       for eps.3 (0,2)
#         for nu.3 (0,1)
#           for p.3 (0,49)
#             for co.3 (0,2)
#               bgemm = ...
# blockIdx.x p.0@co.0@p.1@co.1@.0 (0,392)
#   threadIdx.x p.0@co.0@p.1@co.1@.1 (0,32)
#     unroll vh (0,2)
#       unroll vw (0,2)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             inverse = ...
# blockIdx.x ax0@ax1@ax2@ax3@.0 (0,1568)
#   threadIdx.x ax0@ax1@ax2@ax3@.1 (0,32)
#     T_relu = ...
#
# ================================================================================
# Step 67 : auto_scheduler.PragmaStep(0x7f1c58013378)
# Placeholder: p0, p1, p2
# data_pack auto_unroll: 512
# blockIdx.x p.0@ci.0@p.1@ci.1@.0 (0,392)
#   threadIdx.x p.0@ci.0@p.1@ci.1@.1 (0,32)
#     for eps (0,4)
#       for nu (0,4)
#         for p (blockIdx_x // 8,1)
#           for ci (blockIdx_x % 8 * 32 + threadIdx_x,1)
#             input_tile = ...
#     unroll eps (0,4)
#       unroll nu (0,4)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             data_pack = ...
# blockIdx.x eps.0@nu.0@p.0@co.0@ (0,32)
#   vthread eps.1@nu.1@p.1@co.1@ (0,1)
#     threadIdx.x eps.2@nu.2@p.2@co.2@ (0,32)
#       bgemm.local auto_unroll: 16
#       for eps_c.0 (0,1)
#         for nu_c.0 (0,1)
#           for p_c.0 (0,1)
#             for co_c.0 (0,1)
#               for eps_c.1 (0,1)
#                 for nu_c.1 (0,1)
#                   for p_c.1 (0,1)
#                     for co_c.1 (0,1)
#                       for eps_c.2 (0,1)
#                         for nu_c.2 (0,1)
#                           for p_c.2 (0,1)
#                             for co_c.2 (0,1)
#                               for ci.0 (0,16)
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,64)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       p1.shared = ...
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,98)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       data_pack.shared = ...
#                                 for ci.1 (0,4)
#                                   for eps_c.3 (0,2)
#                                     for nu_c.3 (0,1)
#                                       for p_c.3 (0,49)
#                                         for co_c.3 (0,1)
#                                           for ci.2 (0,4)
#                                             for eps_c.4 (0,1)
#                                               for nu_c.4 (0,1)
#                                                 for p_c.4 (0,1)
#                                                   for co_c.4 (0,2)
#                                                     bgemm.local = ...
#       for eps.3 (0,2)
#         for nu.3 (0,1)
#           for p.3 (0,49)
#             for co.3 (0,2)
#               bgemm = ...
# blockIdx.x p.0@co.0@p.1@co.1@.0 (0,392)
#   threadIdx.x p.0@co.0@p.1@co.1@.1 (0,32)
#     unroll vh (0,2)
#       unroll vw (0,2)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             inverse = ...
# blockIdx.x ax0@ax1@ax2@ax3@.0 (0,1568)
#   threadIdx.x ax0@ax1@ax2@ax3@.1 (0,32)
#     T_relu = ...
#
# ================================================================================

# %%
# VisitAttrs 추가 후 Step 속성 접근 테스트 (고유 타입별)
print("=== transform step 속성 접근 테스트 ===\n")
seen_types = set()
for i, step in enumerate(s.transform_steps):
    # 실제 C++ 타입 확인
    type_key = step.type_key if hasattr(step, 'type_key') else '?'
    # if type_key in seen_types:
    #     continue
    seen_types.add(type_key)
    attrs = [x for x in dir(step) if not x.startswith('_') and x not in ('handle', 'legacy_repr', 'same_as', 'type_key')]
    print(f"Step {i}: type_key={type_key}, python_type={type(step).__name__}, attrs={attrs}")
    for attr in attrs:
        try:
            val = getattr(step, attr)
            print(f"  {attr} = {val}")
        except Exception as e:
            print(f"  {attr} = ERROR: {e}")
    print()
# Out:
# === transform step 속성 접근 테스트 ===
#
# Step 0: type_key=auto_scheduler.ComputeInlineStep, python_type=Object, attrs=['stage_id']
#   stage_id = 11
#
# Step 1: type_key=auto_scheduler.ComputeInlineStep, python_type=Object, attrs=['stage_id']
#   stage_id = 9
#
# Step 2: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 1
#   iter_id = 0
#   stage_id = 8
#
# Step 3: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 1
#   iter_id = 1
#   stage_id = 8
#
# Step 4: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 49
#   inner_to_outer = 1
#   iter_id = 2
#   lengths = [49]
#   stage_id = 8
#
# Step 5: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 256
#   inner_to_outer = 1
#   iter_id = 4
#   lengths = [64]
#   stage_id = 8
#
# Step 6: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 1
#   iter_id = 6
#   stage_id = 8
#
# Step 7: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 1
#   iter_id = 7
#   stage_id = 8
#
# Step 8: type_key=auto_scheduler.ReorderStep, python_type=Object, attrs=['after_ids', 'stage_id']
#   after_ids = [2, 4, 3, 5, 0, 1, 6, 7]
#   stage_id = 8
#
# Step 9: type_key=auto_scheduler.ComputeInlineStep, python_type=Object, attrs=['stage_id']
#   stage_id = 7
#
# Step 10: type_key=auto_scheduler.CacheWriteStep, python_type=Object, attrs=['scope_name', 'stage_id']
#   scope_name = local
#   stage_id = 6
#
# Step 11: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 4
#   inner_to_outer = 1
#   iter_id = 0
#   lengths = [1, 4, 1, 1]
#   stage_id = 6
#
# Step 12: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 4
#   inner_to_outer = 1
#   iter_id = 5
#   lengths = [1, 1, 2, 2]
#   stage_id = 6
#
# Step 13: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 49
#   inner_to_outer = 1
#   iter_id = 10
#   lengths = [1, 1, 7, 1]
#   stage_id = 6
#
# Step 14: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 256
#   inner_to_outer = 1
#   iter_id = 15
#   lengths = [1, 8, 4, 1]
#   stage_id = 6
#
# Step 15: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 256
#   inner_to_outer = 1
#   iter_id = 20
#   lengths = [8, 2]
#   stage_id = 6
#
# Step 16: type_key=auto_scheduler.ReorderStep, python_type=Object, attrs=['after_ids', 'stage_id']
#   after_ids = [0, 5, 10, 15, 1, 6, 11, 16, 2, 7, 12, 17, 20, 21, 3, 8, 13, 18, 22, 4, 9, 14, 19]
#   stage_id = 6
#
# Step 17: type_key=auto_scheduler.FollowSplitStep, python_type=Object, attrs=['iter_id', 'n_split', 'src_step_id', 'stage_id']
#   iter_id = 0
#   n_split = 3
#   src_step_id = 11
#   stage_id = 7
#
# Step 18: type_key=auto_scheduler.FollowSplitStep, python_type=Object, attrs=['iter_id', 'n_split', 'src_step_id', 'stage_id']
#   iter_id = 4
#   n_split = 3
#   src_step_id = 12
#   stage_id = 7
#
# Step 19: type_key=auto_scheduler.FollowSplitStep, python_type=Object, attrs=['iter_id', 'n_split', 'src_step_id', 'stage_id']
#   iter_id = 8
#   n_split = 3
#   src_step_id = 13
#   stage_id = 7
#
# Step 20: type_key=auto_scheduler.FollowSplitStep, python_type=Object, attrs=['iter_id', 'n_split', 'src_step_id', 'stage_id']
#   iter_id = 12
#   n_split = 3
#   src_step_id = 14
#   stage_id = 7
#
# Step 21: type_key=auto_scheduler.ReorderStep, python_type=Object, attrs=['after_ids', 'stage_id']
#   after_ids = [0, 4, 8, 12, 1, 5, 9, 13, 2, 6, 10, 14, 3, 7, 11, 15]
#   stage_id = 7
#
# Step 22: type_key=auto_scheduler.ComputeAtStep, python_type=Object, attrs=['stage_id', 'target_iter_id', 'target_stage_id']
#   stage_id = 6
#   target_iter_id = 11
#   target_stage_id = 7
#
# Step 23: type_key=auto_scheduler.CacheReadStep, python_type=Object, attrs=['reader_stage_ids', 'scope_name', 'stage_id']
#   reader_stage_ids = [6]
#   scope_name = shared
#   stage_id = 5
#
# Step 24: type_key=auto_scheduler.ComputeAtStep, python_type=Object, attrs=['stage_id', 'target_iter_id', 'target_stage_id']
#   stage_id = 6
#   target_iter_id = 12
#   target_stage_id = 7
#
# Step 25: type_key=auto_scheduler.CacheReadStep, python_type=Object, attrs=['reader_stage_ids', 'scope_name', 'stage_id']
#   reader_stage_ids = [7]
#   scope_name = shared
#   stage_id = 4
#
# Step 26: type_key=auto_scheduler.ComputeAtStep, python_type=Object, attrs=['stage_id', 'target_iter_id', 'target_stage_id']
#   stage_id = 5
#   target_iter_id = 12
#   target_stage_id = 8
#
# Step 27: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 1
#   iter_id = 0
#   stage_id = 4
#
# Step 28: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 1
#   iter_id = 1
#   stage_id = 4
#
# Step 29: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 49
#   inner_to_outer = 1
#   iter_id = 2
#   lengths = [49]
#   stage_id = 4
#
# Step 30: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 256
#   inner_to_outer = 1
#   iter_id = 4
#   lengths = [16]
#   stage_id = 4
#
# Step 31: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 1
#   iter_id = 6
#   stage_id = 4
#
# Step 32: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 1
#   iter_id = 7
#   stage_id = 4
#
# Step 33: type_key=auto_scheduler.ReorderStep, python_type=Object, attrs=['after_ids', 'stage_id']
#   after_ids = [2, 4, 3, 5, 0, 1, 6, 7]
#   stage_id = 4
#
# Step 34: type_key=auto_scheduler.ComputeInlineStep, python_type=Object, attrs=['stage_id']
#   stage_id = 3
#
# Step 35: type_key=auto_scheduler.ComputeAtStep, python_type=Object, attrs=['stage_id', 'target_iter_id', 'target_stage_id']
#   stage_id = 2
#   target_iter_id = 3
#   target_stage_id = 4
#
# Step 36: type_key=auto_scheduler.ComputeInlineStep, python_type=Object, attrs=['stage_id']
#   stage_id = 1
#
# Step 37: type_key=auto_scheduler.FuseStep, python_type=Object, attrs=['fused_ids', 'stage_id']
#   fused_ids = [0, 1, 2, 3]
#   stage_id = 15
#
# Step 38: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 50176
#   inner_to_outer = 1
#   iter_id = 0
#   lengths = [32]
#   stage_id = 15
#
# Step 39: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 5
#   iter_id = 0
#   stage_id = 15
#
# Step 40: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 6
#   iter_id = 1
#   stage_id = 15
#
# Step 41: type_key=auto_scheduler.FuseStep, python_type=Object, attrs=['fused_ids', 'stage_id']
#   fused_ids = [0, 1, 2, 3]
#   stage_id = 11
#
# Step 42: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 12544
#   inner_to_outer = 1
#   iter_id = 0
#   lengths = [32]
#   stage_id = 11
#
# Step 43: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 5
#   iter_id = 0
#   stage_id = 11
#
# Step 44: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 6
#   iter_id = 1
#   stage_id = 11
#
# Step 45: type_key=auto_scheduler.FuseStep, python_type=Object, attrs=['fused_ids', 'stage_id']
#   fused_ids = [0, 1, 2, 3]
#   stage_id = 9
#
# Step 46: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 5
#   iter_id = 0
#   stage_id = 9
#
# Step 47: type_key=auto_scheduler.FuseStep, python_type=Object, attrs=['fused_ids', 'stage_id']
#   fused_ids = [1, 2, 3, 4]
#   stage_id = 9
#
# Step 48: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 4
#   iter_id = 1
#   stage_id = 9
#
# Step 49: type_key=auto_scheduler.FuseStep, python_type=Object, attrs=['fused_ids', 'stage_id']
#   fused_ids = [2, 3, 4, 5]
#   stage_id = 9
#
# Step 50: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 6
#   iter_id = 2
#   stage_id = 9
#
# Step 51: type_key=auto_scheduler.FuseStep, python_type=Object, attrs=['fused_ids', 'stage_id']
#   fused_ids = [0, 1, 2, 3]
#   stage_id = 7
#
# Step 52: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 256
#   inner_to_outer = 1
#   iter_id = 0
#   lengths = [1]
#   stage_id = 7
#
# Step 53: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 2
#   iter_id = 1
#   stage_id = 7
#
# Step 54: type_key=auto_scheduler.FollowFusedSplitStep, python_type=Object, attrs=['factor_or_nparts', 'iter_id', 'level', 'src_step_ids', 'stage_id']
#   factor_or_nparts = 1
#   iter_id = 0
#   level = 1
#   src_step_ids = [14, 13, 12, 11]
#   stage_id = 7
#
# Step 55: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 6
#   iter_id = 1
#   stage_id = 7
#
# Step 56: type_key=auto_scheduler.FuseStep, python_type=Object, attrs=['fused_ids', 'stage_id']
#   fused_ids = [0, 1, 2, 3]
#   stage_id = 5
#
# Step 57: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 448
#   inner_to_outer = 1
#   iter_id = 0
#   lengths = [1]
#   stage_id = 5
#
# Step 58: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 2
#   iter_id = 1
#   stage_id = 5
#
# Step 59: type_key=auto_scheduler.FollowFusedSplitStep, python_type=Object, attrs=['factor_or_nparts', 'iter_id', 'level', 'src_step_ids', 'stage_id']
#   factor_or_nparts = 1
#   iter_id = 0
#   level = 1
#   src_step_ids = [14, 13, 12, 11]
#   stage_id = 5
#
# Step 60: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 6
#   iter_id = 1
#   stage_id = 5
#
# Step 61: type_key=auto_scheduler.FuseStep, python_type=Object, attrs=['fused_ids', 'stage_id']
#   fused_ids = [0, 1, 2, 3]
#   stage_id = 4
#
# Step 62: type_key=auto_scheduler.SplitStep, python_type=Object, attrs=['extent', 'inner_to_outer', 'iter_id', 'lengths', 'stage_id']
#   extent = 12544
#   inner_to_outer = 1
#   iter_id = 0
#   lengths = [32]
#   stage_id = 4
#
# Step 63: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 5
#   iter_id = 0
#   stage_id = 4
#
# Step 64: type_key=auto_scheduler.AnnotationStep, python_type=Object, attrs=['annotation', 'iter_id', 'stage_id']
#   annotation = 6
#   iter_id = 1
#   stage_id = 4
#
# Step 65: type_key=auto_scheduler.PragmaStep, python_type=Object, attrs=['iter_id', 'pragma_type', 'stage_id']
#   iter_id = 0
#   pragma_type = auto_unroll_max_step$512
#   stage_id = 4
#
# Step 66: type_key=auto_scheduler.PragmaStep, python_type=Object, attrs=['iter_id', 'pragma_type', 'stage_id']
#   iter_id = 0
#   pragma_type = auto_unroll_max_step$64
#   stage_id = 8
#
# Step 67: type_key=auto_scheduler.PragmaStep, python_type=Object, attrs=['iter_id', 'pragma_type', 'stage_id']
#   iter_id = 0
#   pragma_type = auto_unroll_max_step$1024
#   stage_id = 11

# %%
print(tvm._ffi.get_global_func("auto_scheduler.ReplayStepsPartial")(tasks[10].compute_dag, s, 0))
for i in range(1,len(s.transform_steps)+1):
    partial_state = tvm._ffi.get_global_func("auto_scheduler.ReplayStepsPartial")(tasks[10].compute_dag, s, i)
    # sch, tensors = tasks[10].compute_dag.apply_steps_from_state(partial_state)
    python_code = str(tasks[10].compute_dag.print_python_code_from_state(partial_state))
    print(s.transform_steps[:i])
    print("\n".join(python_code.split("\n")[compute_ops_n:]))


    print(partial_state)
# Out:
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# for vh (0,2)
#   for vw (0,2)
#     for p (0,49)
#       for co (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             inverse = ...
# for n (0,1)
#   for h (0,14)
#     for w (0,14)
#       for co (0,256)
#         conv2d_winograd = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_add = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098)]
# s[T_add].compute_inline()
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# for vh (0,2)
#   for vw (0,2)
#     for p (0,49)
#       for co (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             inverse = ...
# for n (0,1)
#   for h (0,14)
#     for w (0,14)
#       for co (0,256)
#         conv2d_winograd = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# for vh (0,2)
#   for vw (0,2)
#     for p (0,49)
#       for co (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# unroll vh (0,2)
#   for vw (0,2)
#     for p (0,49)
#       for co (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# unroll vh (0,2)
#   unroll vw (0,2)
#     for p (0,49)
#       for co (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# unroll vh (0,2)
#   unroll vw (0,2)
#     for p.0 (0,7)
#       for p.1 (0,7)
#         for co (0,256)
#           for r_a (0,4)
#             for r_b (0,4)
#               inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# unroll vh (0,2)
#   unroll vw (0,2)
#     for p.0 (0,7)
#       for p.1 (0,7)
#         for co.0 (0,128)
#           for co.1 (0,2)
#             for r_a (0,4)
#               for r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# unroll vh (0,2)
#   unroll vw (0,2)
#     for p.0 (0,7)
#       for p.1 (0,7)
#         for co.0 (0,128)
#           for co.1 (0,2)
#             unroll r_a (0,4)
#               for r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# unroll vh (0,2)
#   unroll vw (0,2)
#     for p.0 (0,7)
#       for p.1 (0,7)
#         for co.0 (0,128)
#           for co.1 (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378), auto_scheduler.ReorderStep(0x3c502518)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
# s[inverse].reorder(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i, inverse_vh, inverse_vw, inverse_r_a, inverse_r_b)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for i (0,4)
#   for j (0,2)
#     A = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378), auto_scheduler.ReorderStep(0x3c502518), auto_scheduler.ComputeInlineStep(0x3e260758)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
# s[inverse].reorder(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i, inverse_vh, inverse_vw, inverse_r_a, inverse_r_b)
# s[A].compute_inline()
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         for ci (0,256)
#           bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378), auto_scheduler.ReorderStep(0x3c502518), auto_scheduler.ComputeInlineStep(0x3e260758), auto_scheduler.CacheWriteStep(0x3daea5e8)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
# s[inverse].reorder(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i, inverse_vh, inverse_vw, inverse_r_a, inverse_r_b)
# s[A].compute_inline()
# bgemm_local, = s.cache_write([bgemm], "local")
# bgemm_local_eps_c, bgemm_local_nu_c, bgemm_local_p_c, bgemm_local_co_c, bgemm_local_ci = tuple(bgemm_local.op.axis) + tuple(bgemm_local.op.reduce_axis)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c (0,4)
#   for nu_c (0,4)
#     for p_c (0,49)
#       for co_c (0,256)
#         for ci (0,256)
#           bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378), auto_scheduler.ReorderStep(0x3c502518), auto_scheduler.ComputeInlineStep(0x3e260758), auto_scheduler.CacheWriteStep(0x3daea5e8), auto_scheduler.SplitStep(0x7f1c5805f8a8)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
# s[inverse].reorder(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i, inverse_vh, inverse_vw, inverse_r_a, inverse_r_b)
# s[A].compute_inline()
# bgemm_local, = s.cache_write([bgemm], "local")
# bgemm_local_eps_c, bgemm_local_nu_c, bgemm_local_p_c, bgemm_local_co_c, bgemm_local_ci = tuple(bgemm_local.op.axis) + tuple(bgemm_local.op.reduce_axis)
# bgemm_local_eps_c_o_i, bgemm_local_eps_c_i = s[bgemm_local].split(bgemm_local_eps_c, factor=1)
# bgemm_local_eps_c_o_o_i, bgemm_local_eps_c_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_i, bgemm_local_eps_c_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_o, bgemm_local_eps_c_o_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_o_i, factor=1)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for eps_c.1 (0,1)
#     for eps_c.2 (0,2)
#       for eps_c.3 (0,2)
#         for eps_c.4 (0,1)
#           for nu_c (0,4)
#             for p_c (0,49)
#               for co_c (0,256)
#                 for ci (0,256)
#                   bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378), auto_scheduler.ReorderStep(0x3c502518), auto_scheduler.ComputeInlineStep(0x3e260758), auto_scheduler.CacheWriteStep(0x3daea5e8), auto_scheduler.SplitStep(0x7f1c5805f8a8), auto_scheduler.SplitStep(0x7f1c58118848)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
# s[inverse].reorder(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i, inverse_vh, inverse_vw, inverse_r_a, inverse_r_b)
# s[A].compute_inline()
# bgemm_local, = s.cache_write([bgemm], "local")
# bgemm_local_eps_c, bgemm_local_nu_c, bgemm_local_p_c, bgemm_local_co_c, bgemm_local_ci = tuple(bgemm_local.op.axis) + tuple(bgemm_local.op.reduce_axis)
# bgemm_local_eps_c_o_i, bgemm_local_eps_c_i = s[bgemm_local].split(bgemm_local_eps_c, factor=1)
# bgemm_local_eps_c_o_o_i, bgemm_local_eps_c_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_i, bgemm_local_eps_c_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_o, bgemm_local_eps_c_o_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_o_i, factor=1)
# bgemm_local_nu_c_o_i, bgemm_local_nu_c_i = s[bgemm_local].split(bgemm_local_nu_c, factor=1)
# bgemm_local_nu_c_o_o_i, bgemm_local_nu_c_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_i, bgemm_local_nu_c_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_o, bgemm_local_nu_c_o_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_o_i, factor=1)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for eps_c.1 (0,1)
#     for eps_c.2 (0,2)
#       for eps_c.3 (0,2)
#         for eps_c.4 (0,1)
#           for nu_c.0 (0,4)
#             for nu_c.1 (0,1)
#               for nu_c.2 (0,1)
#                 for nu_c.3 (0,1)
#                   for nu_c.4 (0,1)
#                     for p_c (0,49)
#                       for co_c (0,256)
#                         for ci (0,256)
#                           bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378), auto_scheduler.ReorderStep(0x3c502518), auto_scheduler.ComputeInlineStep(0x3e260758), auto_scheduler.CacheWriteStep(0x3daea5e8), auto_scheduler.SplitStep(0x7f1c5805f8a8), auto_scheduler.SplitStep(0x7f1c58118848), auto_scheduler.SplitStep(0x7f1c58041ef8)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
# s[inverse].reorder(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i, inverse_vh, inverse_vw, inverse_r_a, inverse_r_b)
# s[A].compute_inline()
# bgemm_local, = s.cache_write([bgemm], "local")
# bgemm_local_eps_c, bgemm_local_nu_c, bgemm_local_p_c, bgemm_local_co_c, bgemm_local_ci = tuple(bgemm_local.op.axis) + tuple(bgemm_local.op.reduce_axis)
# bgemm_local_eps_c_o_i, bgemm_local_eps_c_i = s[bgemm_local].split(bgemm_local_eps_c, factor=1)
# bgemm_local_eps_c_o_o_i, bgemm_local_eps_c_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_i, bgemm_local_eps_c_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_o, bgemm_local_eps_c_o_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_o_i, factor=1)
# bgemm_local_nu_c_o_i, bgemm_local_nu_c_i = s[bgemm_local].split(bgemm_local_nu_c, factor=1)
# bgemm_local_nu_c_o_o_i, bgemm_local_nu_c_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_i, bgemm_local_nu_c_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_o, bgemm_local_nu_c_o_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_o_i, factor=1)
# bgemm_local_p_c_o_i, bgemm_local_p_c_i = s[bgemm_local].split(bgemm_local_p_c, factor=1)
# bgemm_local_p_c_o_o_i, bgemm_local_p_c_o_i = s[bgemm_local].split(bgemm_local_p_c_o_i, factor=49)
# bgemm_local_p_c_o_o_o_i, bgemm_local_p_c_o_o_i = s[bgemm_local].split(bgemm_local_p_c_o_o_i, factor=1)
# bgemm_local_p_c_o_o_o_o, bgemm_local_p_c_o_o_o_i = s[bgemm_local].split(bgemm_local_p_c_o_o_o_i, factor=1)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for eps_c.1 (0,1)
#     for eps_c.2 (0,2)
#       for eps_c.3 (0,2)
#         for eps_c.4 (0,1)
#           for nu_c.0 (0,4)
#             for nu_c.1 (0,1)
#               for nu_c.2 (0,1)
#                 for nu_c.3 (0,1)
#                   for nu_c.4 (0,1)
#                     for p_c.0 (0,1)
#                       for p_c.1 (0,1)
#                         for p_c.2 (0,1)
#                           for p_c.3 (0,49)
#                             for p_c.4 (0,1)
#                               for co_c (0,256)
#                                 for ci (0,256)
#                                   bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378), auto_scheduler.ReorderStep(0x3c502518), auto_scheduler.ComputeInlineStep(0x3e260758), auto_scheduler.CacheWriteStep(0x3daea5e8), auto_scheduler.SplitStep(0x7f1c5805f8a8), auto_scheduler.SplitStep(0x7f1c58118848), auto_scheduler.SplitStep(0x7f1c58041ef8), auto_scheduler.SplitStep(0x7f1c5804a9f8)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
# s[inverse].reorder(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i, inverse_vh, inverse_vw, inverse_r_a, inverse_r_b)
# s[A].compute_inline()
# bgemm_local, = s.cache_write([bgemm], "local")
# bgemm_local_eps_c, bgemm_local_nu_c, bgemm_local_p_c, bgemm_local_co_c, bgemm_local_ci = tuple(bgemm_local.op.axis) + tuple(bgemm_local.op.reduce_axis)
# bgemm_local_eps_c_o_i, bgemm_local_eps_c_i = s[bgemm_local].split(bgemm_local_eps_c, factor=1)
# bgemm_local_eps_c_o_o_i, bgemm_local_eps_c_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_i, bgemm_local_eps_c_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_o, bgemm_local_eps_c_o_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_o_i, factor=1)
# bgemm_local_nu_c_o_i, bgemm_local_nu_c_i = s[bgemm_local].split(bgemm_local_nu_c, factor=1)
# bgemm_local_nu_c_o_o_i, bgemm_local_nu_c_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_i, bgemm_local_nu_c_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_o, bgemm_local_nu_c_o_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_o_i, factor=1)
# bgemm_local_p_c_o_i, bgemm_local_p_c_i = s[bgemm_local].split(bgemm_local_p_c, factor=1)
# bgemm_local_p_c_o_o_i, bgemm_local_p_c_o_i = s[bgemm_local].split(bgemm_local_p_c_o_i, factor=49)
# bgemm_local_p_c_o_o_o_i, bgemm_local_p_c_o_o_i = s[bgemm_local].split(bgemm_local_p_c_o_o_i, factor=1)
# bgemm_local_p_c_o_o_o_o, bgemm_local_p_c_o_o_o_i = s[bgemm_local].split(bgemm_local_p_c_o_o_o_i, factor=1)
# bgemm_local_co_c_o_i, bgemm_local_co_c_i = s[bgemm_local].split(bgemm_local_co_c, factor=2)
# bgemm_local_co_c_o_o_i, bgemm_local_co_c_o_i = s[bgemm_local].split(bgemm_local_co_c_o_i, factor=1)
# bgemm_local_co_c_o_o_o_i, bgemm_local_co_c_o_o_i = s[bgemm_local].split(bgemm_local_co_c_o_o_i, factor=16)
# bgemm_local_co_c_o_o_o_o, bgemm_local_co_c_o_o_o_i = s[bgemm_local].split(bgemm_local_co_c_o_o_o_i, factor=1)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for eps_c.1 (0,1)
#     for eps_c.2 (0,2)
#       for eps_c.3 (0,2)
#         for eps_c.4 (0,1)
#           for nu_c.0 (0,4)
#             for nu_c.1 (0,1)
#               for nu_c.2 (0,1)
#                 for nu_c.3 (0,1)
#                   for nu_c.4 (0,1)
#                     for p_c.0 (0,1)
#                       for p_c.1 (0,1)
#                         for p_c.2 (0,1)
#                           for p_c.3 (0,49)
#                             for p_c.4 (0,1)
#                               for co_c.0 (0,8)
#                                 for co_c.1 (0,1)
#                                   for co_c.2 (0,16)
#                                     for co_c.3 (0,1)
#                                       for co_c.4 (0,2)
#                                         for ci (0,256)
#                                           bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378), auto_scheduler.ReorderStep(0x3c502518), auto_scheduler.ComputeInlineStep(0x3e260758), auto_scheduler.CacheWriteStep(0x3daea5e8), auto_scheduler.SplitStep(0x7f1c5805f8a8), auto_scheduler.SplitStep(0x7f1c58118848), auto_scheduler.SplitStep(0x7f1c58041ef8), auto_scheduler.SplitStep(0x7f1c5804a9f8), auto_scheduler.SplitStep(0x7f1c580b6ac8)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
# s[inverse].reorder(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i, inverse_vh, inverse_vw, inverse_r_a, inverse_r_b)
# s[A].compute_inline()
# bgemm_local, = s.cache_write([bgemm], "local")
# bgemm_local_eps_c, bgemm_local_nu_c, bgemm_local_p_c, bgemm_local_co_c, bgemm_local_ci = tuple(bgemm_local.op.axis) + tuple(bgemm_local.op.reduce_axis)
# bgemm_local_eps_c_o_i, bgemm_local_eps_c_i = s[bgemm_local].split(bgemm_local_eps_c, factor=1)
# bgemm_local_eps_c_o_o_i, bgemm_local_eps_c_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_i, bgemm_local_eps_c_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_o, bgemm_local_eps_c_o_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_o_i, factor=1)
# bgemm_local_nu_c_o_i, bgemm_local_nu_c_i = s[bgemm_local].split(bgemm_local_nu_c, factor=1)
# bgemm_local_nu_c_o_o_i, bgemm_local_nu_c_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_i, bgemm_local_nu_c_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_o, bgemm_local_nu_c_o_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_o_i, factor=1)
# bgemm_local_p_c_o_i, bgemm_local_p_c_i = s[bgemm_local].split(bgemm_local_p_c, factor=1)
# bgemm_local_p_c_o_o_i, bgemm_local_p_c_o_i = s[bgemm_local].split(bgemm_local_p_c_o_i, factor=49)
# bgemm_local_p_c_o_o_o_i, bgemm_local_p_c_o_o_i = s[bgemm_local].split(bgemm_local_p_c_o_o_i, factor=1)
# bgemm_local_p_c_o_o_o_o, bgemm_local_p_c_o_o_o_i = s[bgemm_local].split(bgemm_local_p_c_o_o_o_i, factor=1)
# bgemm_local_co_c_o_i, bgemm_local_co_c_i = s[bgemm_local].split(bgemm_local_co_c, factor=2)
# bgemm_local_co_c_o_o_i, bgemm_local_co_c_o_i = s[bgemm_local].split(bgemm_local_co_c_o_i, factor=1)
# bgemm_local_co_c_o_o_o_i, bgemm_local_co_c_o_o_i = s[bgemm_local].split(bgemm_local_co_c_o_o_i, factor=16)
# bgemm_local_co_c_o_o_o_o, bgemm_local_co_c_o_o_o_i = s[bgemm_local].split(bgemm_local_co_c_o_o_o_i, factor=1)
# bgemm_local_ci_o_i, bgemm_local_ci_i = s[bgemm_local].split(bgemm_local_ci, factor=4)
# bgemm_local_ci_o_o, bgemm_local_ci_o_i = s[bgemm_local].split(bgemm_local_ci_o_i, factor=4)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for eps_c.1 (0,1)
#     for eps_c.2 (0,2)
#       for eps_c.3 (0,2)
#         for eps_c.4 (0,1)
#           for nu_c.0 (0,4)
#             for nu_c.1 (0,1)
#               for nu_c.2 (0,1)
#                 for nu_c.3 (0,1)
#                   for nu_c.4 (0,1)
#                     for p_c.0 (0,1)
#                       for p_c.1 (0,1)
#                         for p_c.2 (0,1)
#                           for p_c.3 (0,49)
#                             for p_c.4 (0,1)
#                               for co_c.0 (0,8)
#                                 for co_c.1 (0,1)
#                                   for co_c.2 (0,16)
#                                     for co_c.3 (0,1)
#                                       for co_c.4 (0,2)
#                                         for ci.0 (0,16)
#                                           for ci.1 (0,4)
#                                             for ci.2 (0,4)
#                                               bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378), auto_scheduler.ReorderStep(0x3c502518), auto_scheduler.ComputeInlineStep(0x3e260758), auto_scheduler.CacheWriteStep(0x3daea5e8), auto_scheduler.SplitStep(0x7f1c5805f8a8), auto_scheduler.SplitStep(0x7f1c58118848), auto_scheduler.SplitStep(0x7f1c58041ef8), auto_scheduler.SplitStep(0x7f1c5804a9f8), auto_scheduler.SplitStep(0x7f1c580b6ac8), auto_scheduler.ReorderStep(0x3d5804f8)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
# s[inverse].reorder(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i, inverse_vh, inverse_vw, inverse_r_a, inverse_r_b)
# s[A].compute_inline()
# bgemm_local, = s.cache_write([bgemm], "local")
# bgemm_local_eps_c, bgemm_local_nu_c, bgemm_local_p_c, bgemm_local_co_c, bgemm_local_ci = tuple(bgemm_local.op.axis) + tuple(bgemm_local.op.reduce_axis)
# bgemm_local_eps_c_o_i, bgemm_local_eps_c_i = s[bgemm_local].split(bgemm_local_eps_c, factor=1)
# bgemm_local_eps_c_o_o_i, bgemm_local_eps_c_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_i, bgemm_local_eps_c_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_o, bgemm_local_eps_c_o_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_o_i, factor=1)
# bgemm_local_nu_c_o_i, bgemm_local_nu_c_i = s[bgemm_local].split(bgemm_local_nu_c, factor=1)
# bgemm_local_nu_c_o_o_i, bgemm_local_nu_c_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_i, bgemm_local_nu_c_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_o, bgemm_local_nu_c_o_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_o_i, factor=1)
# bgemm_local_p_c_o_i, bgemm_local_p_c_i = s[bgemm_local].split(bgemm_local_p_c, factor=1)
# bgemm_local_p_c_o_o_i, bgemm_local_p_c_o_i = s[bgemm_local].split(bgemm_local_p_c_o_i, factor=49)
# bgemm_local_p_c_o_o_o_i, bgemm_local_p_c_o_o_i = s[bgemm_local].split(bgemm_local_p_c_o_o_i, factor=1)
# bgemm_local_p_c_o_o_o_o, bgemm_local_p_c_o_o_o_i = s[bgemm_local].split(bgemm_local_p_c_o_o_o_i, factor=1)
# bgemm_local_co_c_o_i, bgemm_local_co_c_i = s[bgemm_local].split(bgemm_local_co_c, factor=2)
# bgemm_local_co_c_o_o_i, bgemm_local_co_c_o_i = s[bgemm_local].split(bgemm_local_co_c_o_i, factor=1)
# bgemm_local_co_c_o_o_o_i, bgemm_local_co_c_o_o_i = s[bgemm_local].split(bgemm_local_co_c_o_o_i, factor=16)
# bgemm_local_co_c_o_o_o_o, bgemm_local_co_c_o_o_o_i = s[bgemm_local].split(bgemm_local_co_c_o_o_o_i, factor=1)
# bgemm_local_ci_o_i, bgemm_local_ci_i = s[bgemm_local].split(bgemm_local_ci, factor=4)
# bgemm_local_ci_o_o, bgemm_local_ci_o_i = s[bgemm_local].split(bgemm_local_ci_o_i, factor=4)
# s[bgemm_local].reorder(bgemm_local_eps_c_o_o_o_o, bgemm_local_nu_c_o_o_o_o, bgemm_local_p_c_o_o_o_o, bgemm_local_co_c_o_o_o_o, bgemm_local_eps_c_o_o_o_i, bgemm_local_nu_c_o_o_o_i, bgemm_local_p_c_o_o_o_i, bgemm_local_co_c_o_o_o_i, bgemm_local_eps_c_o_o_i, bgemm_local_nu_c_o_o_i, bgemm_local_p_c_o_o_i, bgemm_local_co_c_o_o_i, bgemm_local_ci_o_o, bgemm_local_ci_o_i, bgemm_local_eps_c_o_i, bgemm_local_nu_c_o_i, bgemm_local_p_c_o_i, bgemm_local_co_c_o_i, bgemm_local_ci_i, bgemm_local_eps_c_i, bgemm_local_nu_c_i, bgemm_local_p_c_i, bgemm_local_co_c_i)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for nu_c.0 (0,4)
#     for p_c.0 (0,1)
#       for co_c.0 (0,8)
#         for eps_c.1 (0,1)
#           for nu_c.1 (0,1)
#             for p_c.1 (0,1)
#               for co_c.1 (0,1)
#                 for eps_c.2 (0,2)
#                   for nu_c.2 (0,1)
#                     for p_c.2 (0,1)
#                       for co_c.2 (0,16)
#                         for ci.0 (0,16)
#                           for ci.1 (0,4)
#                             for eps_c.3 (0,2)
#                               for nu_c.3 (0,1)
#                                 for p_c.3 (0,49)
#                                   for co_c.3 (0,1)
#                                     for ci.2 (0,4)
#                                       for eps_c.4 (0,1)
#                                         for nu_c.4 (0,1)
#                                           for p_c.4 (0,1)
#                                             for co_c.4 (0,2)
#                                               bgemm.local = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for co (0,256)
#         bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378), auto_scheduler.ReorderStep(0x3c502518), auto_scheduler.ComputeInlineStep(0x3e260758), auto_scheduler.CacheWriteStep(0x3daea5e8), auto_scheduler.SplitStep(0x7f1c5805f8a8), auto_scheduler.SplitStep(0x7f1c58118848), auto_scheduler.SplitStep(0x7f1c58041ef8), auto_scheduler.SplitStep(0x7f1c5804a9f8), auto_scheduler.SplitStep(0x7f1c580b6ac8), auto_scheduler.ReorderStep(0x3d5804f8), auto_scheduler.FollowSplitStep(0x3df10d68)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
# s[inverse].reorder(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i, inverse_vh, inverse_vw, inverse_r_a, inverse_r_b)
# s[A].compute_inline()
# bgemm_local, = s.cache_write([bgemm], "local")
# bgemm_local_eps_c, bgemm_local_nu_c, bgemm_local_p_c, bgemm_local_co_c, bgemm_local_ci = tuple(bgemm_local.op.axis) + tuple(bgemm_local.op.reduce_axis)
# bgemm_local_eps_c_o_i, bgemm_local_eps_c_i = s[bgemm_local].split(bgemm_local_eps_c, factor=1)
# bgemm_local_eps_c_o_o_i, bgemm_local_eps_c_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_i, bgemm_local_eps_c_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_o, bgemm_local_eps_c_o_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_o_i, factor=1)
# bgemm_local_nu_c_o_i, bgemm_local_nu_c_i = s[bgemm_local].split(bgemm_local_nu_c, factor=1)
# bgemm_local_nu_c_o_o_i, bgemm_local_nu_c_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_i, bgemm_local_nu_c_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_o, bgemm_local_nu_c_o_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_o_i, factor=1)
# bgemm_local_p_c_o_i, bgemm_local_p_c_i = s[bgemm_local].split(bgemm_local_p_c, factor=1)
# bgemm_local_p_c_o_o_i, bgemm_local_p_c_o_i = s[bgemm_local].split(bgemm_local_p_c_o_i, factor=49)
# bgemm_local_p_c_o_o_o_i, bgemm_local_p_c_o_o_i = s[bgemm_local].split(bgemm_local_p_c_o_o_i, factor=1)
# bgemm_local_p_c_o_o_o_o, bgemm_local_p_c_o_o_o_i = s[bgemm_local].split(bgemm_local_p_c_o_o_o_i, factor=1)
# bgemm_local_co_c_o_i, bgemm_local_co_c_i = s[bgemm_local].split(bgemm_local_co_c, factor=2)
# bgemm_local_co_c_o_o_i, bgemm_local_co_c_o_i = s[bgemm_local].split(bgemm_local_co_c_o_i, factor=1)
# bgemm_local_co_c_o_o_o_i, bgemm_local_co_c_o_o_i = s[bgemm_local].split(bgemm_local_co_c_o_o_i, factor=16)
# bgemm_local_co_c_o_o_o_o, bgemm_local_co_c_o_o_o_i = s[bgemm_local].split(bgemm_local_co_c_o_o_o_i, factor=1)
# bgemm_local_ci_o_i, bgemm_local_ci_i = s[bgemm_local].split(bgemm_local_ci, factor=4)
# bgemm_local_ci_o_o, bgemm_local_ci_o_i = s[bgemm_local].split(bgemm_local_ci_o_i, factor=4)
# s[bgemm_local].reorder(bgemm_local_eps_c_o_o_o_o, bgemm_local_nu_c_o_o_o_o, bgemm_local_p_c_o_o_o_o, bgemm_local_co_c_o_o_o_o, bgemm_local_eps_c_o_o_o_i, bgemm_local_nu_c_o_o_o_i, bgemm_local_p_c_o_o_o_i, bgemm_local_co_c_o_o_o_i, bgemm_local_eps_c_o_o_i, bgemm_local_nu_c_o_o_i, bgemm_local_p_c_o_o_i, bgemm_local_co_c_o_o_i, bgemm_local_ci_o_o, bgemm_local_ci_o_i, bgemm_local_eps_c_o_i, bgemm_local_nu_c_o_i, bgemm_local_p_c_o_i, bgemm_local_co_c_o_i, bgemm_local_ci_i, bgemm_local_eps_c_i, bgemm_local_nu_c_i, bgemm_local_p_c_i, bgemm_local_co_c_i)
# bgemm_eps_o_i, bgemm_eps_i = s[bgemm].split(bgemm_eps, factor=2)
# bgemm_eps_o_o_i, bgemm_eps_o_i = s[bgemm].split(bgemm_eps_o_i, factor=2)
# bgemm_eps_o_o_o, bgemm_eps_o_o_i = s[bgemm].split(bgemm_eps_o_o_i, factor=1)
#
# Placeholder: p0, p1, p2
# for i0 (0,1)
#   for i1 (0,16)
#     for i2 (0,16)
#       for i3 (0,256)
#         data_pad = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         input_tile = ...
# for i (0,4)
#   for j (0,4)
#     B = ...
# for eps (0,4)
#   for nu (0,4)
#     for p (0,49)
#       for ci (0,256)
#         for r_a (0,4)
#           for r_b (0,4)
#             data_pack = ...
# for eps_c.0 (0,1)
#   for nu_c.0 (0,4)
#     for p_c.0 (0,1)
#       for co_c.0 (0,8)
#         for eps_c.1 (0,1)
#           for nu_c.1 (0,1)
#             for p_c.1 (0,1)
#               for co_c.1 (0,1)
#                 for eps_c.2 (0,2)
#                   for nu_c.2 (0,1)
#                     for p_c.2 (0,1)
#                       for co_c.2 (0,16)
#                         for ci.0 (0,16)
#                           for ci.1 (0,4)
#                             for eps_c.3 (0,2)
#                               for nu_c.3 (0,1)
#                                 for p_c.3 (0,49)
#                                   for co_c.3 (0,1)
#                                     for ci.2 (0,4)
#                                       for eps_c.4 (0,1)
#                                         for nu_c.4 (0,1)
#                                           for p_c.4 (0,1)
#                                             for co_c.4 (0,2)
#                                               bgemm.local = ...
# for eps.0 (0,1)
#   for eps.1 (0,1)
#     for eps.2 (0,2)
#       for eps.3 (0,2)
#         for nu (0,4)
#           for p (0,49)
#             for co (0,256)
#               bgemm = ...
# for p.0 (0,7)
#   for co.0 (0,128)
#     for p.1 (0,7)
#       for co.1 (0,2)
#         unroll vh (0,2)
#           unroll vw (0,2)
#             unroll r_a (0,4)
#               unroll r_b (0,4)
#                 inverse = ...
# for ax0 (0,1)
#   for ax1 (0,14)
#     for ax2 (0,14)
#       for ax3 (0,256)
#         T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378), auto_scheduler.ReorderStep(0x3c502518), auto_scheduler.ComputeInlineStep(0x3e260758), auto_scheduler.CacheWriteStep(0x3daea5e8), auto_scheduler.SplitStep(0x7f1c5805f8a8), auto_scheduler.SplitStep(0x7f1c58118848), auto_scheduler.SplitStep(0x7f1c58041ef8), auto_scheduler.SplitStep(0x7f1c5804a9f8), auto_scheduler.SplitStep(0x7f1c580b6ac8), auto_scheduler.ReorderStep(0x3d5804f8), auto_scheduler.FollowSplitStep(0x3df10d68), auto_scheduler.FollowSplitStep(0x3d5e8888)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
# s[inverse].reorder(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i, inverse_vh, inverse_vw, inverse_r_a, inverse_r_b)
# s[A].compute_inline()
# bgemm_local, = s.cache_write([bgemm], "local")
# bgemm_local_eps_c, bgemm_local_nu_c, bgemm_local_p_c, bgemm_local_co_c, bgemm_local_ci = tuple(bgemm_local.op.axis) + tuple(bgemm_local.op.reduce_axis)
# bgemm_local_eps_c_o_i, bgemm_local_eps_c_i = s[bgemm_local].split(bgemm_local_eps_c, factor=1)
# ...
#                                       data_pack.shared = ...
#                                 for ci.1 (0,4)
#                                   for eps_c.3 (0,2)
#                                     for nu_c.3 (0,1)
#                                       for p_c.3 (0,49)
#                                         for co_c.3 (0,1)
#                                           for ci.2 (0,4)
#                                             for eps_c.4 (0,1)
#                                               for nu_c.4 (0,1)
#                                                 for p_c.4 (0,1)
#                                                   for co_c.4 (0,2)
#                                                     bgemm.local = ...
#       for eps.3 (0,2)
#         for nu.3 (0,1)
#           for p.3 (0,49)
#             for co.3 (0,2)
#               bgemm = ...
# blockIdx.x p.0@co.0@p.1@co.1@.0 (0,392)
#   threadIdx.x p.0@co.0@p.1@co.1@.1 (0,32)
#     unroll vh (0,2)
#       unroll vw (0,2)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             inverse = ...
# blockIdx.x ax0@ax1@ax2@ax3@.0 (0,1568)
#   threadIdx.x ax0@ax1@ax2@ax3@.1 (0,32)
#     T_relu = ...
#
# [auto_scheduler.ComputeInlineStep(0x3c4ec098), auto_scheduler.ComputeInlineStep(0x3ddd1278), auto_scheduler.AnnotationStep(0x3deb4a08), auto_scheduler.AnnotationStep(0x3caf0c38), auto_scheduler.SplitStep(0x7f1c58090258), auto_scheduler.SplitStep(0x7f1c580d1d58), auto_scheduler.AnnotationStep(0x3df78598), auto_scheduler.AnnotationStep(0x3db9e378), auto_scheduler.ReorderStep(0x3c502518), auto_scheduler.ComputeInlineStep(0x3e260758), auto_scheduler.CacheWriteStep(0x3daea5e8), auto_scheduler.SplitStep(0x7f1c5805f8a8), auto_scheduler.SplitStep(0x7f1c58118848), auto_scheduler.SplitStep(0x7f1c58041ef8), auto_scheduler.SplitStep(0x7f1c5804a9f8), auto_scheduler.SplitStep(0x7f1c580b6ac8), auto_scheduler.ReorderStep(0x3d5804f8), auto_scheduler.FollowSplitStep(0x3df10d68), auto_scheduler.FollowSplitStep(0x3d5e8888), auto_scheduler.FollowSplitStep(0x3dea1508), auto_scheduler.FollowSplitStep(0x3c8e61d8), auto_scheduler.ReorderStep(0x3e3bde78), auto_scheduler.ComputeAtStep(0x3df83878), auto_scheduler.CacheReadStep(0x3c9dba38), auto_scheduler.ComputeAtStep(0x3d562048), auto_scheduler.CacheReadStep(0x3db9d4d8), auto_scheduler.ComputeAtStep(0x3deb4998), auto_scheduler.AnnotationStep(0x3dec3128), auto_scheduler.AnnotationStep(0x3c8ec508), auto_scheduler.SplitStep(0x7f1c58106a58), auto_scheduler.SplitStep(0x7f1c58005518), auto_scheduler.AnnotationStep(0x3caf4248), auto_scheduler.AnnotationStep(0x3dae6a08), auto_scheduler.ReorderStep(0x3de14eb8), auto_scheduler.ComputeInlineStep(0x3d416ab8), auto_scheduler.ComputeAtStep(0x3ae7daf8), auto_scheduler.ComputeInlineStep(0x3ae7bdf8), auto_scheduler.FuseStep(0x7f1c58062ab8), auto_scheduler.SplitStep(0x7f1c5803dd98), auto_scheduler.AnnotationStep(0x7f1c58019ae8), auto_scheduler.AnnotationStep(0x7f1c58005b28), auto_scheduler.FuseStep(0x7f1c580a02e8), auto_scheduler.SplitStep(0x7f1c58026e18), auto_scheduler.AnnotationStep(0x7f1c58078228), auto_scheduler.AnnotationStep(0x7f1c58074188), auto_scheduler.FuseStep(0x7f1c580cf968), auto_scheduler.AnnotationStep(0x7f1c5802d5f8), auto_scheduler.FuseStep(0x7f1c58083e98), auto_scheduler.AnnotationStep(0x7f1c58016748), auto_scheduler.FuseStep(0x7f1c58098628), auto_scheduler.AnnotationStep(0x7f1c58059098), auto_scheduler.FuseStep(0x7f1c58061ac8), auto_scheduler.SplitStep(0x7f1c5800dff8), auto_scheduler.AnnotationStep(0x7f1c5802a578), auto_scheduler.FollowFusedSplitStep(0x7f1c580028d8), auto_scheduler.AnnotationStep(0x7f1c58026758), auto_scheduler.FuseStep(0x7f1c5807e7c8), auto_scheduler.SplitStep(0x7f1c5808fd78), auto_scheduler.AnnotationStep(0x7f1c58065648), auto_scheduler.FollowFusedSplitStep(0x7f1c5805d498), auto_scheduler.AnnotationStep(0x7f1c58055a58), auto_scheduler.FuseStep(0x7f1c580269e8), auto_scheduler.SplitStep(0x7f1c5801cc78), auto_scheduler.AnnotationStep(0x7f1c58054858), auto_scheduler.AnnotationStep(0x7f1c580317f8), auto_scheduler.PragmaStep(0x7f1c5801d5e8), auto_scheduler.PragmaStep(0x7f1c58054948), auto_scheduler.PragmaStep(0x7f1c58013378)]
# s[T_add].compute_inline()
# s[conv2d_winograd].compute_inline()
# s[inverse].unroll(inverse_vh)
# s[inverse].unroll(inverse_vw)
# inverse_p_o, inverse_p_i = s[inverse].split(inverse_p, factor=7)
# inverse_co_o, inverse_co_i = s[inverse].split(inverse_co, factor=2)
# s[inverse].unroll(inverse_r_a)
# s[inverse].unroll(inverse_r_b)
# s[inverse].reorder(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i, inverse_vh, inverse_vw, inverse_r_a, inverse_r_b)
# s[A].compute_inline()
# bgemm_local, = s.cache_write([bgemm], "local")
# bgemm_local_eps_c, bgemm_local_nu_c, bgemm_local_p_c, bgemm_local_co_c, bgemm_local_ci = tuple(bgemm_local.op.axis) + tuple(bgemm_local.op.reduce_axis)
# bgemm_local_eps_c_o_i, bgemm_local_eps_c_i = s[bgemm_local].split(bgemm_local_eps_c, factor=1)
# bgemm_local_eps_c_o_o_i, bgemm_local_eps_c_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_i, bgemm_local_eps_c_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_i, factor=2)
# bgemm_local_eps_c_o_o_o_o, bgemm_local_eps_c_o_o_o_i = s[bgemm_local].split(bgemm_local_eps_c_o_o_o_i, factor=1)
# bgemm_local_nu_c_o_i, bgemm_local_nu_c_i = s[bgemm_local].split(bgemm_local_nu_c, factor=1)
# bgemm_local_nu_c_o_o_i, bgemm_local_nu_c_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_i, bgemm_local_nu_c_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_i, factor=1)
# bgemm_local_nu_c_o_o_o_o, bgemm_local_nu_c_o_o_o_i = s[bgemm_local].split(bgemm_local_nu_c_o_o_o_i, factor=1)
# bgemm_local_p_c_o_i, bgemm_local_p_c_i = s[bgemm_local].split(bgemm_local_p_c, factor=1)
# bgemm_local_p_c_o_o_i, bgemm_local_p_c_o_i = s[bgemm_local].split(bgemm_local_p_c_o_i, factor=49)
# bgemm_local_p_c_o_o_o_i, bgemm_local_p_c_o_o_i = s[bgemm_local].split(bgemm_local_p_c_o_o_i, factor=1)
# bgemm_local_p_c_o_o_o_o, bgemm_local_p_c_o_o_o_i = s[bgemm_local].split(bgemm_local_p_c_o_o_o_i, factor=1)
# bgemm_local_co_c_o_i, bgemm_local_co_c_i = s[bgemm_local].split(bgemm_local_co_c, factor=2)
# bgemm_local_co_c_o_o_i, bgemm_local_co_c_o_i = s[bgemm_local].split(bgemm_local_co_c_o_i, factor=1)
# bgemm_local_co_c_o_o_o_i, bgemm_local_co_c_o_o_i = s[bgemm_local].split(bgemm_local_co_c_o_o_i, factor=16)
# bgemm_local_co_c_o_o_o_o, bgemm_local_co_c_o_o_o_i = s[bgemm_local].split(bgemm_local_co_c_o_o_o_i, factor=1)
# bgemm_local_ci_o_i, bgemm_local_ci_i = s[bgemm_local].split(bgemm_local_ci, factor=4)
# bgemm_local_ci_o_o, bgemm_local_ci_o_i = s[bgemm_local].split(bgemm_local_ci_o_i, factor=4)
# s[bgemm_local].reorder(bgemm_local_eps_c_o_o_o_o, bgemm_local_nu_c_o_o_o_o, bgemm_local_p_c_o_o_o_o, bgemm_local_co_c_o_o_o_o, bgemm_local_eps_c_o_o_o_i, bgemm_local_nu_c_o_o_o_i, bgemm_local_p_c_o_o_o_i, bgemm_local_co_c_o_o_o_i, bgemm_local_eps_c_o_o_i, bgemm_local_nu_c_o_o_i, bgemm_local_p_c_o_o_i, bgemm_local_co_c_o_o_i, bgemm_local_ci_o_o, bgemm_local_ci_o_i, bgemm_local_eps_c_o_i, bgemm_local_nu_c_o_i, bgemm_local_p_c_o_i, bgemm_local_co_c_o_i, bgemm_local_ci_i, bgemm_local_eps_c_i, bgemm_local_nu_c_i, bgemm_local_p_c_i, bgemm_local_co_c_i)
# bgemm_eps_o_i, bgemm_eps_i = s[bgemm].split(bgemm_eps, factor=2)
# bgemm_eps_o_o_i, bgemm_eps_o_i = s[bgemm].split(bgemm_eps_o_i, factor=2)
# bgemm_eps_o_o_o, bgemm_eps_o_o_i = s[bgemm].split(bgemm_eps_o_o_i, factor=1)
# bgemm_nu_o_i, bgemm_nu_i = s[bgemm].split(bgemm_nu, factor=1)
# bgemm_nu_o_o_i, bgemm_nu_o_i = s[bgemm].split(bgemm_nu_o_i, factor=1)
# bgemm_nu_o_o_o, bgemm_nu_o_o_i = s[bgemm].split(bgemm_nu_o_o_i, factor=1)
# bgemm_p_o_i, bgemm_p_i = s[bgemm].split(bgemm_p, factor=49)
# bgemm_p_o_o_i, bgemm_p_o_i = s[bgemm].split(bgemm_p_o_i, factor=1)
# bgemm_p_o_o_o, bgemm_p_o_o_i = s[bgemm].split(bgemm_p_o_o_i, factor=1)
# bgemm_co_o_i, bgemm_co_i = s[bgemm].split(bgemm_co, factor=2)
# bgemm_co_o_o_i, bgemm_co_o_i = s[bgemm].split(bgemm_co_o_i, factor=16)
# bgemm_co_o_o_o, bgemm_co_o_o_i = s[bgemm].split(bgemm_co_o_o_i, factor=1)
# s[bgemm].reorder(bgemm_eps_o_o_o, bgemm_nu_o_o_o, bgemm_p_o_o_o, bgemm_co_o_o_o, bgemm_eps_o_o_i, bgemm_nu_o_o_i, bgemm_p_o_o_i, bgemm_co_o_o_i, bgemm_eps_o_i, bgemm_nu_o_i, bgemm_p_o_i, bgemm_co_o_i, bgemm_eps_i, bgemm_nu_i, bgemm_p_i, bgemm_co_i)
# s[bgemm_local].compute_at(s[bgemm], bgemm_co_o_i)
# p1_shared = s.cache_read(p1, "shared", [bgemm_local])
# p1_shared_ax0, p1_shared_ax1, p1_shared_ax2, p1_shared_ax3 = tuple(p1_shared.op.axis)
# s[p1_shared].compute_at(s[bgemm_local], bgemm_local_ci_o_o)
# data_pack_shared = s.cache_read(data_pack, "shared", [bgemm_local])
# data_pack_shared_ax0, data_pack_shared_ax1, data_pack_shared_ax2, data_pack_shared_ax3 = tuple(data_pack_shared.op.axis)
# s[data_pack_shared].compute_at(s[bgemm_local], bgemm_local_ci_o_o)
# s[data_pack].unroll(data_pack_eps)
# s[data_pack].unroll(data_pack_nu)
# data_pack_p_o, data_pack_p_i = s[data_pack].split(data_pack_p, factor=1)
# data_pack_ci_o, data_pack_ci_i = s[data_pack].split(data_pack_ci, factor=16)
# s[data_pack].unroll(data_pack_r_a)
# s[data_pack].unroll(data_pack_r_b)
# s[data_pack].reorder(data_pack_p_o, data_pack_ci_o, data_pack_p_i, data_pack_ci_i, data_pack_eps, data_pack_nu, data_pack_r_a, data_pack_r_b)
# s[B].compute_inline()
# s[input_tile].compute_at(s[data_pack], data_pack_ci_i)
# s[data_pad].compute_inline()
# T_relu_ax0_ax1_fused_ax2_fused_ax3_fused = s[T_relu].fuse(T_relu_ax0, T_relu_ax1, T_relu_ax2, T_relu_ax3)
# T_relu_ax0_ax1_fused_ax2_fused_ax3_fused_o, T_relu_ax0_ax1_fused_ax2_fused_ax3_fused_i = s[T_relu].split(T_relu_ax0_ax1_fused_ax2_fused_ax3_fused, factor=32)
# s[T_relu].bind(T_relu_ax0_ax1_fused_ax2_fused_ax3_fused_o, te.thread_axis("blockIdx.x"))
# s[T_relu].bind(T_relu_ax0_ax1_fused_ax2_fused_ax3_fused_i, te.thread_axis("threadIdx.x"))
# inverse_p_o_co_o_fused_p_i_fused_co_i_fused = s[inverse].fuse(inverse_p_o, inverse_co_o, inverse_p_i, inverse_co_i)
# inverse_p_o_co_o_fused_p_i_fused_co_i_fused_o, inverse_p_o_co_o_fused_p_i_fused_co_i_fused_i = s[inverse].split(inverse_p_o_co_o_fused_p_i_fused_co_i_fused, factor=32)
# s[inverse].bind(inverse_p_o_co_o_fused_p_i_fused_co_i_fused_o, te.thread_axis("blockIdx.x"))
# s[inverse].bind(inverse_p_o_co_o_fused_p_i_fused_co_i_fused_i, te.thread_axis("threadIdx.x"))
# bgemm_eps_o_o_o_nu_o_o_o_fused_p_o_o_o_fused_co_o_o_o_fused = s[bgemm].fuse(bgemm_eps_o_o_o, bgemm_nu_o_o_o, bgemm_p_o_o_o, bgemm_co_o_o_o)
# s[bgemm].bind(bgemm_eps_o_o_o_nu_o_o_o_fused_p_o_o_o_fused_co_o_o_o_fused, te.thread_axis("blockIdx.x"))
# bgemm_eps_o_o_i_nu_o_o_i_fused_p_o_o_i_fused_co_o_o_i_fused = s[bgemm].fuse(bgemm_eps_o_o_i, bgemm_nu_o_o_i, bgemm_p_o_o_i, bgemm_co_o_o_i)
# s[bgemm].bind(bgemm_eps_o_o_i_nu_o_o_i_fused_p_o_o_i_fused_co_o_o_i_fused, te.thread_axis("vthread"))
# bgemm_eps_o_i_nu_o_i_fused_p_o_i_fused_co_o_i_fused = s[bgemm].fuse(bgemm_eps_o_i, bgemm_nu_o_i, bgemm_p_o_i, bgemm_co_o_i)
# s[bgemm].bind(bgemm_eps_o_i_nu_o_i_fused_p_o_i_fused_co_o_i_fused, te.thread_axis("threadIdx.x"))
# p1_shared_ax0_ax1_fused_ax2_fused_ax3_fused = s[p1_shared].fuse(p1_shared_ax0, p1_shared_ax1, p1_shared_ax2, p1_shared_ax3)
# p1_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o, p1_shared_ax0_ax1_fused_ax2_fused_ax3_fused_i = s[p1_shared].split(p1_shared_ax0_ax1_fused_ax2_fused_ax3_fused, factor=1)
# s[p1_shared].vectorize(p1_shared_ax0_ax1_fused_ax2_fused_ax3_fused_i)
# p1_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o_o, p1_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o_i = s[p1_shared].split(p1_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o, factor=32)
# s[p1_shared].bind(p1_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o_i, te.thread_axis("threadIdx.x"))
# data_pack_shared_ax0_ax1_fused_ax2_fused_ax3_fused = s[data_pack_shared].fuse(data_pack_shared_ax0, data_pack_shared_ax1, data_pack_shared_ax2, data_pack_shared_ax3)
# data_pack_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o, data_pack_shared_ax0_ax1_fused_ax2_fused_ax3_fused_i = s[data_pack_shared].split(data_pack_shared_ax0_ax1_fused_ax2_fused_ax3_fused, factor=1)
# s[data_pack_shared].vectorize(data_pack_shared_ax0_ax1_fused_ax2_fused_ax3_fused_i)
# data_pack_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o_o, data_pack_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o_i = s[data_pack_shared].split(data_pack_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o, factor=32)
# s[data_pack_shared].bind(data_pack_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o_i, te.thread_axis("threadIdx.x"))
# data_pack_p_o_ci_o_fused_p_i_fused_ci_i_fused = s[data_pack].fuse(data_pack_p_o, data_pack_ci_o, data_pack_p_i, data_pack_ci_i)
# data_pack_p_o_ci_o_fused_p_i_fused_ci_i_fused_o, data_pack_p_o_ci_o_fused_p_i_fused_ci_i_fused_i = s[data_pack].split(data_pack_p_o_ci_o_fused_p_i_fused_ci_i_fused, factor=32)
# s[data_pack].bind(data_pack_p_o_ci_o_fused_p_i_fused_ci_i_fused_o, te.thread_axis("blockIdx.x"))
# s[data_pack].bind(data_pack_p_o_ci_o_fused_p_i_fused_ci_i_fused_i, te.thread_axis("threadIdx.x"))
# s[data_pack].pragma(data_pack_p_o_ci_o_fused_p_i_fused_ci_i_fused_o, "auto_unroll_max_step", 512)
# s[data_pack].pragma(data_pack_p_o_ci_o_fused_p_i_fused_ci_i_fused_o, "unroll_explicit", True)
# s[bgemm_local].pragma(bgemm_local_eps_c_o_o_o_o, "auto_unroll_max_step", 16)
# s[bgemm_local].pragma(bgemm_local_eps_c_o_o_o_o, "unroll_explicit", True)
# s[inverse].pragma(inverse_p_o_co_o_fused_p_i_fused_co_i_fused_o, "auto_unroll_max_step", 64)
# s[inverse].pragma(inverse_p_o_co_o_fused_p_i_fused_co_i_fused_o, "unroll_explicit", True)
#
# Placeholder: p0, p1, p2
# data_pack auto_unroll: 512
# blockIdx.x p.0@ci.0@p.1@ci.1@.0 (0,392)
#   threadIdx.x p.0@ci.0@p.1@ci.1@.1 (0,32)
#     for eps (0,4)
#       for nu (0,4)
#         for p (blockIdx_x // 8,1)
#           for ci (blockIdx_x % 8 * 32 + threadIdx_x,1)
#             input_tile = ...
#     unroll eps (0,4)
#       unroll nu (0,4)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             data_pack = ...
# blockIdx.x eps.0@nu.0@p.0@co.0@ (0,32)
#   vthread eps.1@nu.1@p.1@co.1@ (0,1)
#     threadIdx.x eps.2@nu.2@p.2@co.2@ (0,32)
#       bgemm.local auto_unroll: 16
#       for eps_c.0 (0,1)
#         for nu_c.0 (0,1)
#           for p_c.0 (0,1)
#             for co_c.0 (0,1)
#               for eps_c.1 (0,1)
#                 for nu_c.1 (0,1)
#                   for p_c.1 (0,1)
#                     for co_c.1 (0,1)
#                       for eps_c.2 (0,1)
#                         for nu_c.2 (0,1)
#                           for p_c.2 (0,1)
#                             for co_c.2 (0,1)
#                               for ci.0 (0,16)
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,64)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       p1.shared = ...
#                                 for ax0@ax1@ax2@ax3@.0.0 (0,98)
#                                   threadIdx.x ax0@ax1@ax2@ax3@.0.1 (0,32)
#                                     vectorize ax0@ax1@ax2@ax3@.1 (0,1)
#                                       data_pack.shared = ...
#                                 for ci.1 (0,4)
#                                   for eps_c.3 (0,2)
#                                     for nu_c.3 (0,1)
#                                       for p_c.3 (0,49)
#                                         for co_c.3 (0,1)
#                                           for ci.2 (0,4)
#                                             for eps_c.4 (0,1)
#                                               for nu_c.4 (0,1)
#                                                 for p_c.4 (0,1)
#                                                   for co_c.4 (0,2)
#                                                     bgemm.local = ...
#       for eps.3 (0,2)
#         for nu.3 (0,1)
#           for p.3 (0,49)
#             for co.3 (0,2)
#               bgemm = ...
# inverse auto_unroll: 64
# blockIdx.x p.0@co.0@p.1@co.1@.0 (0,392)
#   threadIdx.x p.0@co.0@p.1@co.1@.1 (0,32)
#     unroll vh (0,2)
#       unroll vw (0,2)
#         unroll r_a (0,4)
#           unroll r_b (0,4)
#             inverse = ...
# blockIdx.x ax0@ax1@ax2@ax3@.0 (0,1568)
#   threadIdx.x ax0@ax1@ax2@ax3@.1 (0,32)
#     T_relu = ...

# %%
"""
GetPerStoreFeaturesWorkerFunc의 TIR pass 파이프라인을 순차 적용하며 TIR 출력 확인
C++ feature.cc의 GPU pass 순서를 그대로 재현:
  Phase 0: InjectPrefetch → StorageFlatten(64)
  Phase 1: NarrowDataType(32) → Simplify → VectorizeLoop → InjectVirtualThread → StorageRewrite → Simplify
  검증:    VerifyGPUCode
"""
import tvm
from tvm import tir

task = tasks[10]
print(f"Task: {task.desc}")
print(f"Hardware: shared_mem={task.hardware_params.max_shared_memory_per_block}, "
      f"threads={task.hardware_params.max_threads_per_block}, "
      f"vector_bytes={task.hardware_params.vector_unit_bytes}, "
      f"max_vthread={task.hardware_params.max_vthread_extent}")
print("=" * 80)

# 1) ApplySteps: State → te::Schedule
sch, tensors = task.compute_dag.apply_steps_from_state(s)

# 2) normalize (C++에서는 normalize_for_feature_extraction 사용)
sch = sch.normalize()

# 3) ScheduleToModule: te::Schedule → TIR IRModule
mod = tvm.driver.lower(sch, args=tensors, name="main")

print(">>> [0] ScheduleToModule 직후 (원본 TIR)")
print(mod.script())
print("=" * 80)

# GPU TIR pass 파이프라인 (feature.cc와 동일한 순서)
pass_sequence = [
    ("InjectPrefetch",       tir.transform.InjectPrefetch()),
    ("StorageFlatten(64)",   tir.transform.StorageFlatten(64)),
    ("NarrowDataType(32)",   tir.transform.NarrowDataType(32)),
    ("Simplify #1",          tir.transform.Simplify()),
    ("VectorizeLoop",        tir.transform.VectorizeLoop(True)),
    ("InjectVirtualThread",  tir.transform.InjectVirtualThread()),
    ("StorageRewrite",       tir.transform.StorageRewrite()),
    ("Simplify #2",          tir.transform.Simplify()),
]

for i, (name, p) in enumerate(pass_sequence):
    try:
        mod = p(mod)
        print(f">>> [{i+1}] {name} 적용 후")
        print(mod.script())
        print("=" * 80)
    except Exception as e:
        print(f">>> [{i+1}] {name} 적용 중 에러: {e}")
        print("=" * 80)
        break

# VerifyGPUCode (분석 pass - 에러만 출력)
print(">>> [9] VerifyGPUCode 검증")
gpu_params = {
    "max_shared_memory_per_block": task.hardware_params.max_shared_memory_per_block,
    "max_local_memory_per_block":  task.hardware_params.max_local_memory_per_block,
    "max_threads_per_block":       task.hardware_params.max_threads_per_block,
    "max_vector_bytes":            task.hardware_params.vector_unit_bytes,
    "max_vthread":                 task.hardware_params.max_vthread_extent,
}
try:
    prim_func = mod["main"]
    result = tvm.tir.analysis.verify_gpu_code(prim_func, gpu_params)
    print(f"  결과: {result}")
    if result:
        print("  ⚠️ GPU 제약 위반 발견!")
    else:
        print("  ✅ GPU 제약 통과")
except Exception as e:
    print(f"  에러: {e}")
print("=" * 80)

# 최종 Simplify (feature extraction 전 마지막 단계)
print(">>> [10] 최종 Simplify")
try:
    final_mod = tir.transform.Simplify()(mod)
    print(final_mod.script())
except Exception as e:
    print(f"  에러: {e}")
print("=" * 80)
# Out:
# Task: vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_2
# Hardware: shared_mem=49152, threads=1024, vector_bytes=16, max_vthread=8
# ================================================================================
# >>> [0] ScheduleToModule 직후 (원본 TIR)
# # from tvm.script import ir as I
# # from tvm.script import tir as T
#
# @I.ir_module
# class Module:
#     @T.prim_func
#     def main(p0: T.Buffer((1, 14, 14, 256), "float32"), p1: T.Buffer((4, 4, 256, 256), "float32"), p2: T.Buffer((1, 1, 1, 256), "float32"), T_relu: T.Buffer((1, 14, 14, 256), "float32")):
#         T.func_attr({"from_legacy_te_schedule": T.bool(True), "tir.noalias": T.bool(True)})
#         data_pack = T.allocate([200704], "float32", "global")
#         bgemm = T.allocate([200704], "float32", "global")
#         data_pack_1 = T.Buffer((200704,), data=data_pack)
#         with T.launch_thread("blockIdx.x", 392) as blockIdx_x:
#             input_tile = T.allocate([16], "float32", "local")
#             threadIdx_x = T.launch_thread("threadIdx.x", 32)
#             input_tile_1 = T.Buffer((16,), data=input_tile, scope="local")
#             for eps, nu in T.grid(4, 4):
#                 p0_1 = T.Buffer((50176,), data=p0.data)
#                 input_tile_1[eps * 4 + nu] = T.if_then_else(1 <= blockIdx_x // 56 * 2 + eps and blockIdx_x // 56 * 2 + eps < 15 and 1 <= blockIdx_x % 56 // 8 * 2 + nu and blockIdx_x % 56 // 8 * 2 + nu < 15, p0_1[blockIdx_x // 56 * 7168 + eps * 3584 + blockIdx_x % 56 // 8 * 512 + nu * 256 + blockIdx_x % 8 * 32 + threadIdx_x - 3840], T.float32(0))
#             data_pack_1[blockIdx_x * 32 + threadIdx_x] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x] = data_pack_1[blockIdx_x * 32 + threadIdx_x] + input_tile_1[0]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x] = data_pack_1[blockIdx_x * 32 + threadIdx_x] + input_tile_1[2] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x] = data_pack_1[blockIdx_x * 32 + threadIdx_x] + input_tile_1[8] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x] = data_pack_1[blockIdx_x * 32 + threadIdx_x] + input_tile_1[10] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] + input_tile_1[1] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] + input_tile_1[2]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] + input_tile_1[9] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] + input_tile_1[10] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] + input_tile_1[1]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] + input_tile_1[2]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] + input_tile_1[9] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] + input_tile_1[10] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] + input_tile_1[1] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] + input_tile_1[3]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] + input_tile_1[9] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] + input_tile_1[11] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] + input_tile_1[4] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] + input_tile_1[6] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] + input_tile_1[8]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] + input_tile_1[10] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] + input_tile_1[5] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] + input_tile_1[6] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] + input_tile_1[9] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] + input_tile_1[10]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] + input_tile_1[5] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] + input_tile_1[6] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] + input_tile_1[9]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] + input_tile_1[10]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] + input_tile_1[5] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] + input_tile_1[7] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] + input_tile_1[9] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] + input_tile_1[11]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] + input_tile_1[4]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] + input_tile_1[6] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] + input_tile_1[8]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] + input_tile_1[10] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] + input_tile_1[5] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] + input_tile_1[6]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] + input_tile_1[9] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] + input_tile_1[10]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] + input_tile_1[5]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] + input_tile_1[6]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] + input_tile_1[9]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] + input_tile_1[10]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] + input_tile_1[5] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] + input_tile_1[7]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] + input_tile_1[9] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] + input_tile_1[11]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] + input_tile_1[4] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] + input_tile_1[6] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] + input_tile_1[12]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] + input_tile_1[14] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] + input_tile_1[5] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] + input_tile_1[6] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] + input_tile_1[13] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] + input_tile_1[14]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] + input_tile_1[5] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] + input_tile_1[6] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] + input_tile_1[13]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] + input_tile_1[14]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 188160] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 188160] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 188160] + input_tile_1[5] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 188160] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 188160] + input_tile_1[7] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 188160] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 188160] + input_tile_1[13] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 188160] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 188160] + input_tile_1[15]
#         bgemm_1 = T.Buffer((200704,), data=bgemm)
#         with T.launch_thread("blockIdx.x", 32) as blockIdx_x:
#             bgemm_local = T.allocate([196], "float32", "local")
#             data_pack_shared = T.allocate([3136], "float32", "shared")
#             p1_shared = T.allocate([2048], "float32", "shared")
#             threadIdx_x = T.launch_thread("threadIdx.x", 32)
#             bgemm_local_1 = T.Buffer((196,), data=bgemm_local, scope="local")
#             for eps_c_outer_inner_init, p_c_outer_inner_init in T.grid(2, 49):
#                 cse_var_1: T.int32 = eps_c_outer_inner_init * 98 + p_c_outer_inner_init * 2
#                 bgemm_local_1[cse_var_1] = T.float32(0)
#                 bgemm_local_1[cse_var_1 + 1] = T.float32(0)
#             for ci_outer_outer in range(16):
#                 data_pack_shared_1 = T.Buffer((3136,), data=data_pack_shared, scope="shared")
#                 for ax0_ax1_fused_ax2_fused_ax3_fused_outer_outer in range(98):
#                     threadIdx_x_1 = T.launch_thread("threadIdx.x", 32)
#                     data_pack_shared_1[ax0_ax1_fused_ax2_fused_ax3_fused_outer_outer * 32 + threadIdx_x_1] = data_pack_1[(ax0_ax1_fused_ax2_fused_ax3_fused_outer_outer * 2 + threadIdx_x_1 // 16) // 49 * 50176 + blockIdx_x // 8 * 12544 + (ax0_ax1_fused_ax2_fused_ax3_fused_outer_outer * 2 + threadIdx_x_1 // 16) % 49 * 256 + ci_outer_outer * 16 + threadIdx_x_1 % 16]
#                 p1_shared_1 = T.Buffer((2048,), data=p1_shared, scope="shared")
#                 for ax0_ax1_fused_ax2_fused_ax3_fused_outer_outer in range(64):
#                     threadIdx_x_1 = T.launch_thread("threadIdx.x", 32)
#                     p1_1 = T.Buffer((1048576,), data=p1.data)
#                     p1_shared_1[ax0_ax1_fused_ax2_fused_ax3_fused_outer_outer * 32 + threadIdx_x_1] = p1_1[ax0_ax1_fused_ax2_fused_ax3_fused_outer_outer // 16 * 262144 + blockIdx_x * 8192 + ax0_ax1_fused_ax2_fused_ax3_fused_outer_outer % 16 * 512 + threadIdx_x_1 // 16 * 256 + ci_outer_outer * 16 + threadIdx_x_1 % 16]
#                 for ci_outer_inner, eps_c_outer_inner, p_c_outer_inner in T.grid(4, 2, 49):
#                     cse_var_4: T.int32 = ci_outer_inner * 4
#                     cse_var_3: T.int32 = eps_c_outer_inner * 98 + p_c_outer_inner * 2
#                     cse_var_2: T.int32 = cse_var_3 + 1
#                     bgemm_local_1[cse_var_3] = bgemm_local_1[cse_var_3] + data_pack_shared_1[threadIdx_x // 16 * 1568 + eps_c_outer_inner * 784 + p_c_outer_inner * 16 + cse_var_4] * p1_shared_1[threadIdx_x // 16 * 1024 + eps_c_outer_inner * 512 + threadIdx_x % 16 * 32 + cse_var_4]
#                     bgemm_local_1[cse_var_2] = bgemm_local_1[cse_var_2] + data_pack_shared_1[threadIdx_x // 16 * 1568 + eps_c_outer_inner * 784 + p_c_outer_inner * 16 + cse_var_4] * p1_shared_1[threadIdx_x // 16 * 1024 + eps_c_outer_inner * 512 + threadIdx_x % 16 * 32 + cse_var_4 + 16]
#                     bgemm_local_1[cse_var_3] = bgemm_local_1[cse_var_3] + data_pack_shared_1[threadIdx_x // 16 * 1568 + eps_c_outer_inner * 784 + p_c_outer_inner * 16 + cse_var_4 + 1] * p1_shared_1[threadIdx_x // 16 * 1024 + eps_c_outer_inner * 512 + threadIdx_x % 16 * 32 + cse_var_4 + 1]
#                     bgemm_local_1[cse_var_2] = bgemm_local_1[cse_var_2] + data_pack_shared_1[threadIdx_x // 16 * 1568 + eps_c_outer_inner * 784 + p_c_outer_inner * 16 + cse_var_4 + 1] * p1_shared_1[threadIdx_x // 16 * 1024 + eps_c_outer_inner * 512 + threadIdx_x % 16 * 32 + cse_var_4 + 17]
#                     bgemm_local_1[cse_var_3] = bgemm_local_1[cse_var_3] + data_pack_shared_1[threadIdx_x // 16 * 1568 + eps_c_outer_inner * 784 + p_c_outer_inner * 16 + cse_var_4 + 2] * p1_shared_1[threadIdx_x // 16 * 1024 + eps_c_outer_inner * 512 + threadIdx_x % 16 * 32 + cse_var_4 + 2]
#                     bgemm_local_1[cse_var_2] = bgemm_local_1[cse_var_2] + data_pack_shared_1[threadIdx_x // 16 * 1568 + eps_c_outer_inner * 784 + p_c_outer_inner * 16 + cse_var_4 + 2] * p1_shared_1[threadIdx_x // 16 * 1024 + eps_c_outer_inner * 512 + threadIdx_x % 16 * 32 + cse_var_4 + 18]
#                     bgemm_local_1[cse_var_3] = bgemm_local_1[cse_var_3] + data_pack_shared_1[threadIdx_x // 16 * 1568 + eps_c_outer_inner * 784 + p_c_outer_inner * 16 + cse_var_4 + 3] * p1_shared_1[threadIdx_x // 16 * 1024 + eps_c_outer_inner * 512 + threadIdx_x % 16 * 32 + cse_var_4 + 3]
#                     bgemm_local_1[cse_var_2] = bgemm_local_1[cse_var_2] + data_pack_shared_1[threadIdx_x // 16 * 1568 + eps_c_outer_inner * 784 + p_c_outer_inner * 16 + cse_var_4 + 3] * p1_shared_1[threadIdx_x // 16 * 1024 + eps_c_outer_inner * 512 + threadIdx_x % 16 * 32 + cse_var_4 + 19]
#             for eps_inner, p_inner, co_inner in T.grid(2, 49, 2):
#                 bgemm_1[threadIdx_x // 16 * 100352 + eps_inner * 50176 + blockIdx_x // 8 * 12544 + p_inner * 256 + blockIdx_x % 8 * 32 + threadIdx_x % 16 * 2 + co_inner] = bgemm_local_1[eps_inner * 98 + p_inner * 2 + co_inner]
#         data_pack_2 = T.Buffer((50176,), data=data_pack)
#         with T.launch_thread("blockIdx.x", 392) as blockIdx_x:
#             threadIdx_x = T.launch_thread("threadIdx.x", 32)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] = T.float32(0)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 50176]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 62720]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 75264]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 100352]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 112896]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 125440]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = T.float32(0)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 62720] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 75264]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 87808]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 112896] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 125440]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 137984]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = T.float32(0)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 50176] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 62720] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 75264] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 100352]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 112896]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 125440]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 150528]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 163072]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 175616]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = T.float32(0)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 62720] * T.float32(-1) * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 75264] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 87808] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 112896] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 125440]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 137984]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 163072] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 175616]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 188160]
#         blockIdx_x = T.launch_thread("blockIdx.x", 1568)
#         threadIdx_x = T.launch_thread("threadIdx.x", 32)
#         T_relu_1 = T.Buffer((50176,), data=T_relu.data)
#         p2_1 = T.Buffer((256,), data=p2.data)
#         T_relu_1[blockIdx_x * 32 + threadIdx_x] = T.max(data_pack_2[blockIdx_x % 224 // 112 * 25088 + blockIdx_x % 16 // 8 * 12544 + blockIdx_x // 224 * 1792 + blockIdx_x % 112 // 16 * 256 + blockIdx_x % 8 * 32 + threadIdx_x] + p2_1[blockIdx_x % 8 * 32 + threadIdx_x], T.float32(0))
# ================================================================================
# >>> [1] InjectPrefetch 적용 후
# # from tvm.script import ir as I
# # from tvm.script import tir as T
#
# @I.ir_module
# class Module:
#     @T.prim_func
#     def main(p0: T.Buffer((1, 14, 14, 256), "float32"), p1: T.Buffer((4, 4, 256, 256), "float32"), p2: T.Buffer((1, 1, 1, 256), "float32"), T_relu: T.Buffer((1, 14, 14, 256), "float32")):
#         T.func_attr({"from_legacy_te_schedule": T.bool(True), "tir.noalias": T.bool(True)})
#         data_pack = T.allocate([200704], "float32", "global")
#         bgemm = T.allocate([200704], "float32", "global")
#         data_pack_1 = T.Buffer((200704,), data=data_pack)
#         with T.launch_thread("blockIdx.x", 392) as blockIdx_x:
#             input_tile = T.allocate([16], "float32", "local")
#             threadIdx_x = T.launch_thread("threadIdx.x", 32)
#             input_tile_1 = T.Buffer((16,), data=input_tile, scope="local")
#             for eps, nu in T.grid(4, 4):
#                 p0_1 = T.Buffer((50176,), data=p0.data)
#                 input_tile_1[eps * 4 + nu] = T.if_then_else(1 <= blockIdx_x // 56 * 2 + eps and blockIdx_x // 56 * 2 + eps < 15 and 1 <= blockIdx_x % 56 // 8 * 2 + nu and blockIdx_x % 56 // 8 * 2 + nu < 15, p0_1[blockIdx_x // 56 * 7168 + eps * 3584 + blockIdx_x % 56 // 8 * 512 + nu * 256 + blockIdx_x % 8 * 32 + threadIdx_x - 3840], T.float32(0))
#             data_pack_1[blockIdx_x * 32 + threadIdx_x] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x] = data_pack_1[blockIdx_x * 32 + threadIdx_x] + input_tile_1[0]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x] = data_pack_1[blockIdx_x * 32 + threadIdx_x] + input_tile_1[2] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x] = data_pack_1[blockIdx_x * 32 + threadIdx_x] + input_tile_1[8] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x] = data_pack_1[blockIdx_x * 32 + threadIdx_x] + input_tile_1[10] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] + input_tile_1[1] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] + input_tile_1[2]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] + input_tile_1[9] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 12544] + input_tile_1[10] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] + input_tile_1[1]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] + input_tile_1[2]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] + input_tile_1[9] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 25088] + input_tile_1[10] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] + input_tile_1[1] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] + input_tile_1[3]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] + input_tile_1[9] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 37632] + input_tile_1[11] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] + input_tile_1[4] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] + input_tile_1[6] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] + input_tile_1[8]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 50176] + input_tile_1[10] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] + input_tile_1[5] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] + input_tile_1[6] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] + input_tile_1[9] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 62720] + input_tile_1[10]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] + input_tile_1[5] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] + input_tile_1[6] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] + input_tile_1[9]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 75264] + input_tile_1[10]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] + input_tile_1[5] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] + input_tile_1[7] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] + input_tile_1[9] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 87808] + input_tile_1[11]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] + input_tile_1[4]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] + input_tile_1[6] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] + input_tile_1[8]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 100352] + input_tile_1[10] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] + input_tile_1[5] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] + input_tile_1[6]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] + input_tile_1[9] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 112896] + input_tile_1[10]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] + input_tile_1[5]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] + input_tile_1[6]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] + input_tile_1[9]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 125440] + input_tile_1[10]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] + input_tile_1[5] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] + input_tile_1[7]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] + input_tile_1[9] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 137984] + input_tile_1[11]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] + input_tile_1[4] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] + input_tile_1[6] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] + input_tile_1[12]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 150528] + input_tile_1[14] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] + input_tile_1[5] * T.float32(-1) * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] + input_tile_1[6] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] + input_tile_1[13] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 163072] + input_tile_1[14]
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] = T.float32(0)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] + input_tile_1[5] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] + input_tile_1[6] * T.float32(-1)
#             data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] = data_pack_1[blockIdx_x * 32 + threadIdx_x + 175616] + input_tile_1[13]
# ...
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 112896]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 125440]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = T.float32(0)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 62720] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 75264]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 87808]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 112896] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 125440]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 12544] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 137984]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = T.float32(0)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 50176] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 62720] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 75264] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 100352]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 112896]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 125440]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 150528]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 163072]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 25088] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 175616]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = T.float32(0)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 62720] * T.float32(-1) * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 75264] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 87808] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 112896] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 125440]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 137984]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 163072] * T.float32(-1)
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 175616]
#             data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] = data_pack_2[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 37632] + bgemm_1[blockIdx_x // 56 * 1792 + (blockIdx_x * 2 + threadIdx_x // 2) % 7 * 256 + (blockIdx_x % 56 * 16 + threadIdx_x // 2) // 7 * 2 + threadIdx_x % 2 + 188160]
#         blockIdx_x = T.launch_thread("blockIdx.x", 1568)
#         threadIdx_x = T.launch_thread("threadIdx.x", 32)
#         T_relu_1 = T.Buffer((50176,), data=T_relu.data)
#         p2_1 = T.Buffer((256,), data=p2.data)
#         T_relu_1[blockIdx_x * 32 + threadIdx_x] = T.max(data_pack_2[blockIdx_x % 224 // 112 * 25088 + blockIdx_x % 16 // 8 * 12544 + blockIdx_x // 224 * 1792 + blockIdx_x % 112 // 16 * 256 + blockIdx_x % 8 * 32 + threadIdx_x] + p2_1[blockIdx_x % 8 * 32 + threadIdx_x], T.float32(0))
# ================================================================================
